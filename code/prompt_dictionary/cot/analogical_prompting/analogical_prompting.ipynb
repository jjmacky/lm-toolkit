# %%
from datasets import load_dataset

math_dataset = load_dataset("hendrycks/competition_math", split="test")

# %% [markdown]
# ## Phase 1. Simple test with single problem.
# Let's do a simple test. We'll:
# 1. Choose a random math problem from the MATH test dataset.
# 2. Ask the model to solve it using the standard zero-shot.
# 3. Print out the model answer.

# %%
import ollama
import random

rand_entry = random.choice(math_dataset)
rand_problem = f"{rand_entry['problem']} \n\n As you solve the problem think step-by-step. Explain the solution and enclose the ultimate answer in \\boxed{{}} with no text additional text explanation."

def math_answerer(math_problem):
    model = 'llama3'
    messages = [
        {
            'role': 'user',
            'content': math_problem
        }
    ]

    # Make the request to the Ollama API
    response = ollama.chat(model=model, messages=messages, stream=False)
    return response["message"]["content"]

model_full_solution = math_answerer(rand_problem)

print(f"The random entry chosen from MATH is: {rand_entry}")
print("----")
print(f"The random problem is: {rand_problem}")
print("----")
print(f"The model full solution is: {model_full_solution}.")
# Out:
# The random entry chosen from MATH is: {'problem': 'If $*$ represents an operation defined by $a*b=a^b+b$, find $(1*2)*3$.', 'level': 'Level 2', 'type': 'Algebra', 'solution': 'We have: $(1*2)*3=(1^2+2)*3=3*3=3^3+3=27+3=\\boxed{30}$.'}
# ----
# The random problem is: If $*$ represents an operation defined by $a*b=a^b+b$, find $(1*2)*3$.
#
#  As you solve the problem think step-by-step. Explain the solution and enclose the ultimate answer in \boxed{} with no text additional text explanation.
# ----
# The model full solution is: Let's break it down step by step:
#
# $(1*2)*3$ means we need to evaluate $1^2+2$, and then multiply the result by 3.
#
# To find $(1*2)$, we substitute 1 and 2 into the operation definition: $1*2=1^2+2=1+2=3$
#
# So now we have $(3)*3$. Again, we substitute 3 into the operation definition: $3*3=3^3+3=27+3=30$
#
# Therefore:
#
# \boxed{30}.

# %% [markdown]
# ## Phase 2: Now extract the answer and compare to the official anwser
# We'll build on Phase 1 adding in new functions to extract the final \boxed{} answer from the model and compare it to the offical answer from MATH.

# %%
import re

# Function to extract the **last** \boxed{}.
# In the simplest case (e.g. Phase 1) the model is likely to output only one \boxed{} solution.
# However, the analogical reasoning prompt requests the model think about problems and solutions
# to related problems, enclosing those in \boxed{} before solving the problem at hand, which
# should be the last \boxed{} statement.
def find_closing_boxed(text):
    matches = re.finditer(r'\\boxed\{', text) # Find all answers
    start_index = [match.end() for match in matches][-1] # Get the last \boxed{ answer
    substring = text[start_index:]
    brace_count = 1

    for end_index, char in enumerate(substring, start = start_index):
        if char == '{':
            brace_count += 1
        elif char == '}':
            brace_count -= 1
        else:
            continue

        if brace_count == 0:
            return [start_index, end_index]
        
    # Return None if no matching brace is found (though this should not happen in well-formed strings)
    return [start_index, -1]

def extract_final_answer(math_solution):
    start_index, end_index = find_closing_boxed(math_solution)
    return math_solution[start_index:end_index].strip()

model_final_answer = extract_final_answer(model_full_solution)
offical_final_answer = extract_final_answer(rand_entry["solution"])

print(f"The full model solution is: {model_full_solution}")
print("----")
print(f"The final model answer is: {model_final_answer}")
print("----")
print(f"The official answer is: {offical_final_answer}")
print("----")
print(f"Do the answers match: {model_final_answer  == offical_final_answer}")
# Out:
# The full model solution is: Let's break it down step by step:
#
# $(1*2)*3$ means we need to evaluate $1^2+2$, and then multiply the result by 3.
#
# To find $(1*2)$, we substitute 1 and 2 into the operation definition: $1*2=1^2+2=1+2=3$
#
# So now we have $(3)*3$. Again, we substitute 3 into the operation definition: $3*3=3^3+3=27+3=30$
#
# Therefore:
#
# \boxed{30}
# ----
# The final model answer is: 30
# ----
# The official answer is: 30
# ----
# Do the answers match: True

# %%
rand_problem = random.choice(math_dataset)

analogical_prompt = f"""Your task is to tackle mathematical problems. When presented with a math problem, recall relevant problems as examples. Afterward, proceed to solve the initial problem.

# Problem: {rand_problem['problem']}

# Instructions:
## Relevant Problems:
Recall three examples of math problems that are relevant to the initial problem. Your problems should be distinct from each other and from the initial problem (e.g., involving different numbers and names). For each problem:
- After "Q: ", describe the problem
- After "A: ", explain the solution and enclose the ultimate answer in \\boxed{{}}.

## Solve the Initial Problem: Q: Copy and paste the initial problem here. A: Explain the solution and enclose the ultimate answer in \\boxed{{}} here."""

model_full_solution = math_answerer(analogical_prompt)

model_final_answer = extract_final_answer(model_full_solution)
offical_final_answer = extract_final_answer(rand_entry["solution"])

print(f"The full model solution is: {model_full_solution}")
print("----")
print(f"The final model answer is: {model_final_answer}")
print("----")
print(f"The official answer is: {offical_final_answer}")
print("----")
print(f"Do the answers match: {model_final_answer  == offical_final_answer}")
# Out:
# The full model solution is: I'm ready to tackle this mathematical challenge!
#
# **Relevant Problems:**
#
# 1. **Q:** Suppose $a$ and $b$ are inversely proportional. If $a=12$ when $b=4$, find the value of $b$ when $a=8$.
# **A:** $\boxed{6}$
# To solve this problem, we can set up a proportionality equation: $\frac{a}{b} = k$, where $k$ is the constant of proportionality. Substituting given values, we get $\frac{12}{4}=k$. Then, substituting $a=8$, we find that $b=6$.
#
# 2. **Q:** Suppose $x$ and $y$ are inversely proportional. If $x=16$ when $y=2$, find the value of $y$ when $x=10$.
# **A:** $\boxed{4}$
# Using a proportionality equation, we get $\frac{x}{y}=k$. Substituting given values, we find that $k=\frac{16}{2}=8$. Then, substituting $x=10$, we find that $y=\frac{10}{8}=\boxed{\frac{5}{4}}$.
#
# 3. **Q:** Suppose $p$ and $q$ are inversely proportional. If $p=15$ when $q=3$, find the value of $q$ when $p=20$.
# **A:** $\boxed{\frac{1}{2}}$
# Using a proportionality equation, we get $\frac{p}{q}=k$. Substituting given values, we find that $k=\frac{15}{3}=5$. Then, substituting $p=20$, we find that $q=\frac{20}{5}=\boxed{\frac{4}{1}}$.
#
# **Solve the Initial Problem:**
#
# Q: Suppose $c$ and $d$ are inversely proportional. If $c=9$ when $d=8$, find the value of $d$ when $c=6$.
# A: Since $c$ and $d$ are inversely proportional, we can set up a proportionality equation: $\frac{c}{d}=k$, where $k$ is the constant of proportionality. Substituting given values, we get $\frac{9}{8}=k$. Then, substituting $c=6$, we find that $d=\frac{8\cdot 6}{9}=\boxed{16/3}$.
#
# Let me know if you need further assistance!
# ----
# The final model answer is: 16/3
# ----
# The official answer is: 30
# ----
# Do the answers match: False

# %%
import ollama
import random
import re
import time
import json
from datasets import load_dataset

math_dataset = load_dataset("hendrycks/competition_math", split="test")

def math_answerer(math_problem, retries = 3, delay=5):
    model = 'llama3'
    messages = [
        {
            'role': 'user',
            'content': math_problem
        }
    ]

    attempt = 0
    while attempt < retries:
        try:
            response = ollama.chat(model=model, messages=messages, stream=False)
            return response["message"]["content"]
        
        except Exception as e:
            attempt += 1
            print(f"Encountered error {e}. Waiting {delay} seconds and retrying. Attempt{attempt}...")
            time.sleep(delay)

    print("All retries failed.")
    return None


# Function to extract the **last** \boxed{}.
# In the simplest case (e.g. Phase 1) the model is likely to output only one \boxed{} solution.
# However, the analogical reasoning prompt requests the model think about problems and solutions
# to related problems, enclosing those in \boxed{} before solving the problem at hand, which
# should be the last \boxed{} statement.
def find_closing_boxed(text):
    if text is None:
        return [None, None]
    
    matches = list(re.finditer(r'\\boxed\{', text)) # Find all answers
    if not matches:
        return [None, None]
    
    start_index = matches[-1].end() # Get the last \boxed{ answer
    substring = text[start_index:]
    brace_count = 1

    for end_index, char in enumerate(substring, start = start_index):
        if char == '{':
            brace_count += 1
        elif char == '}':
            brace_count -= 1
        else:
            continue

        if brace_count == 0:
            return [start_index, end_index]
        
    # Return None if no matching brace is found (though this should not happen in well-formed strings)
    return [start_index, -1]

def extract_final_answer(math_solution):
    if math_solution is None:
        return None
    start_index, end_index = find_closing_boxed(math_solution)
    return math_solution[start_index:end_index].strip()

# Initialize result dictionary
cot_results = {}
cot_prompt = f"{rand_problem} \n\n As you solve the problem think step-by-step. Explain the solution and enclose the ultimate answer in \\boxed{{}} with no text additional text explanation."
# Randomly sample indices
random.seed(39)  # Seed for reproducibility if needed
rand_indices = random.sample(range(len(math_dataset)), 500)

epochs = 5
for epoch in range(1, epochs + 1):
    cot_results[epoch] = {}

    for idx, rand_problem_index in enumerate(rand_indices, start=1):
        print(f"Epoch: {epoch}, Problem: {idx}.")
        rand_problem = math_dataset[rand_problem_index]["problem"]
        cot_prompt = f"{rand_problem} \n\n Solve the problem by thinking step by step. Explain the solution and enclose the ultimate answer in \\boxed{{}} with no additional text explanation."
        model_full_solution = math_answerer(cot_prompt)
        model_final_answer = extract_final_answer(model_full_solution)
        official_final_answer = extract_final_answer(math_dataset[rand_problem_index]["solution"])

        cot_results[epoch][idx] = {
            "problem_index": rand_problem_index,
            "model_full_solution": model_full_solution,
            "model_final_answer": model_final_answer,
            "official_final_answer": official_final_answer,
            "answer_correct?": model_final_answer == official_final_answer
        }

with open('cot_results.json', 'w') as outfile:
    json.dump(cot_results, outfile, indent=4)
# Out:
# Epoch: 1, Problem: 1.
# Epoch: 1, Problem: 2.
# Epoch: 1, Problem: 3.
# Epoch: 1, Problem: 4.
# Epoch: 1, Problem: 5.
# Epoch: 1, Problem: 6.
# Epoch: 1, Problem: 7.
# Epoch: 1, Problem: 8.
# Epoch: 1, Problem: 9.
# Epoch: 1, Problem: 10.
# Epoch: 1, Problem: 11.
# Epoch: 1, Problem: 12.
# Epoch: 1, Problem: 13.
# Epoch: 1, Problem: 14.
# Epoch: 1, Problem: 15.
# Epoch: 1, Problem: 16.
# Epoch: 1, Problem: 17.
# Epoch: 1, Problem: 18.
# Epoch: 1, Problem: 19.
# Epoch: 1, Problem: 20.
# Epoch: 1, Problem: 21.
# Epoch: 1, Problem: 22.
# Epoch: 1, Problem: 23.
# Epoch: 1, Problem: 24.
# Epoch: 1, Problem: 25.
# Epoch: 1, Problem: 26.
# Epoch: 1, Problem: 27.
# Epoch: 1, Problem: 28.
# Epoch: 1, Problem: 29.
# Epoch: 1, Problem: 30.
# Epoch: 1, Problem: 31.
# Epoch: 1, Problem: 32.
# Epoch: 1, Problem: 33.
# Epoch: 1, Problem: 34.
# Epoch: 1, Problem: 35.
# Epoch: 1, Problem: 36.
# Epoch: 1, Problem: 37.
# Epoch: 1, Problem: 38.
# Epoch: 1, Problem: 39.
# Epoch: 1, Problem: 40.
# Epoch: 1, Problem: 41.
# Epoch: 1, Problem: 42.
# Epoch: 1, Problem: 43.
# Epoch: 1, Problem: 44.
# Epoch: 1, Problem: 45.
# Epoch: 1, Problem: 46.
# Epoch: 1, Problem: 47.
# Epoch: 1, Problem: 48.
# Epoch: 1, Problem: 49.
# Epoch: 1, Problem: 50.
# Epoch: 1, Problem: 51.
# Epoch: 1, Problem: 52.
# Epoch: 1, Problem: 53.
# Epoch: 1, Problem: 54.
# Epoch: 1, Problem: 55.
# Epoch: 1, Problem: 56.
# Epoch: 1, Problem: 57.
# Epoch: 1, Problem: 58.
# Epoch: 1, Problem: 59.
# Epoch: 1, Problem: 60.
# Epoch: 1, Problem: 61.
# Epoch: 1, Problem: 62.
# Epoch: 1, Problem: 63.
# Epoch: 1, Problem: 64.
# Epoch: 1, Problem: 65.
# Epoch: 1, Problem: 66.
# Epoch: 1, Problem: 67.
# Epoch: 1, Problem: 68.
# Epoch: 1, Problem: 69.
# Epoch: 1, Problem: 70.
# Epoch: 1, Problem: 71.
# Epoch: 1, Problem: 72.
# Epoch: 1, Problem: 73.
# Epoch: 1, Problem: 74.
# Epoch: 1, Problem: 75.
# Epoch: 1, Problem: 76.
# Epoch: 1, Problem: 77.
# Epoch: 1, Problem: 78.
# Epoch: 1, Problem: 79.
# Epoch: 1, Problem: 80.
# Epoch: 1, Problem: 81.
# Epoch: 1, Problem: 82.
# Epoch: 1, Problem: 83.
# Epoch: 1, Problem: 84.
# Epoch: 1, Problem: 85.
# Epoch: 1, Problem: 86.
# Epoch: 1, Problem: 87.
# Epoch: 1, Problem: 88.
# Epoch: 1, Problem: 89.
# Epoch: 1, Problem: 90.
# Epoch: 1, Problem: 91.
# Epoch: 1, Problem: 92.
# Epoch: 1, Problem: 93.
# Epoch: 1, Problem: 94.
# Epoch: 1, Problem: 95.
# Epoch: 1, Problem: 96.
# Epoch: 1, Problem: 97.
# Epoch: 1, Problem: 98.
# Epoch: 1, Problem: 99.
# Epoch: 1, Problem: 100.
# Epoch: 1, Problem: 101.
# Epoch: 1, Problem: 102.
# Epoch: 1, Problem: 103.
# Epoch: 1, Problem: 104.
# Epoch: 1, Problem: 105.
# Epoch: 1, Problem: 106.
# Epoch: 1, Problem: 107.
# Epoch: 1, Problem: 108.
# Epoch: 1, Problem: 109.
# Epoch: 1, Problem: 110.
# Epoch: 1, Problem: 111.
# Epoch: 1, Problem: 112.
# Epoch: 1, Problem: 113.
# Epoch: 1, Problem: 114.
# Epoch: 1, Problem: 115.
# Epoch: 1, Problem: 116.
# Epoch: 1, Problem: 117.
# Epoch: 1, Problem: 118.
# Epoch: 1, Problem: 119.
# Epoch: 1, Problem: 120.
# Epoch: 1, Problem: 121.
# Epoch: 1, Problem: 122.
# Epoch: 1, Problem: 123.
# Epoch: 1, Problem: 124.
# Epoch: 1, Problem: 125.
# Epoch: 1, Problem: 126.
# Epoch: 1, Problem: 127.
# Epoch: 1, Problem: 128.
# Epoch: 1, Problem: 129.
# Epoch: 1, Problem: 130.
# Epoch: 1, Problem: 131.
# Epoch: 1, Problem: 132.
# Epoch: 1, Problem: 133.
# Epoch: 1, Problem: 134.
# Epoch: 1, Problem: 135.
# Epoch: 1, Problem: 136.
# Epoch: 1, Problem: 137.
# Epoch: 1, Problem: 138.
# Epoch: 1, Problem: 139.
# Epoch: 1, Problem: 140.
# Epoch: 1, Problem: 141.
# Epoch: 1, Problem: 142.
# Epoch: 1, Problem: 143.
# Epoch: 1, Problem: 144.
# Epoch: 1, Problem: 145.
# Epoch: 1, Problem: 146.
# Epoch: 1, Problem: 147.
# Epoch: 1, Problem: 148.
# Epoch: 1, Problem: 149.
# Epoch: 1, Problem: 150.
# Epoch: 1, Problem: 151.
# Epoch: 1, Problem: 152.
# Epoch: 1, Problem: 153.
# Epoch: 1, Problem: 154.
# Epoch: 1, Problem: 155.
# Epoch: 1, Problem: 156.
# Epoch: 1, Problem: 157.
# Epoch: 1, Problem: 158.
# Epoch: 1, Problem: 159.
# Epoch: 1, Problem: 160.
# Epoch: 1, Problem: 161.
# Epoch: 1, Problem: 162.
# Epoch: 1, Problem: 163.
# Epoch: 1, Problem: 164.
# Epoch: 1, Problem: 165.
# Epoch: 1, Problem: 166.
# Epoch: 1, Problem: 167.
# Epoch: 1, Problem: 168.
# Epoch: 1, Problem: 169.
# Epoch: 1, Problem: 170.
# Epoch: 1, Problem: 171.
# Epoch: 1, Problem: 172.
# Epoch: 1, Problem: 173.
# Epoch: 1, Problem: 174.
# Epoch: 1, Problem: 175.
# Epoch: 1, Problem: 176.
# Epoch: 1, Problem: 177.
# Epoch: 1, Problem: 178.
# Epoch: 1, Problem: 179.
# Epoch: 1, Problem: 180.
# Epoch: 1, Problem: 181.
# Epoch: 1, Problem: 182.
# Epoch: 1, Problem: 183.
# Epoch: 1, Problem: 184.
# Epoch: 1, Problem: 185.
# Epoch: 1, Problem: 186.
# Epoch: 1, Problem: 187.
# Epoch: 1, Problem: 188.
# Epoch: 1, Problem: 189.
# Epoch: 1, Problem: 190.
# Epoch: 1, Problem: 191.
# Epoch: 1, Problem: 192.
# Epoch: 1, Problem: 193.
# Epoch: 1, Problem: 194.
# Epoch: 1, Problem: 195.
# Epoch: 1, Problem: 196.
# Epoch: 1, Problem: 197.
# Epoch: 1, Problem: 198.
# Epoch: 1, Problem: 199.
# Epoch: 1, Problem: 200.
# Epoch: 1, Problem: 201.
# Epoch: 1, Problem: 202.
# Epoch: 1, Problem: 203.
# Epoch: 1, Problem: 204.
# Epoch: 1, Problem: 205.
# Epoch: 1, Problem: 206.
# Epoch: 1, Problem: 207.
# Epoch: 1, Problem: 208.
# Epoch: 1, Problem: 209.
# Epoch: 1, Problem: 210.
# Epoch: 1, Problem: 211.
# Epoch: 1, Problem: 212.
# Epoch: 1, Problem: 213.
# Epoch: 1, Problem: 214.
# Epoch: 1, Problem: 215.
# Epoch: 1, Problem: 216.
# Epoch: 1, Problem: 217.
# Epoch: 1, Problem: 218.
# Epoch: 1, Problem: 219.
# Epoch: 1, Problem: 220.
# Epoch: 1, Problem: 221.
# Epoch: 1, Problem: 222.
# Epoch: 1, Problem: 223.
# Epoch: 1, Problem: 224.
# Epoch: 1, Problem: 225.
# Epoch: 1, Problem: 226.
# Epoch: 1, Problem: 227.
# Epoch: 1, Problem: 228.
# Epoch: 1, Problem: 229.
# Epoch: 1, Problem: 230.
# Epoch: 1, Problem: 231.
# Epoch: 1, Problem: 232.
# Epoch: 1, Problem: 233.
# Epoch: 1, Problem: 234.
# Epoch: 1, Problem: 235.
# Epoch: 1, Problem: 236.
# Epoch: 1, Problem: 237.
# Epoch: 1, Problem: 238.
# Epoch: 1, Problem: 239.
# Epoch: 1, Problem: 240.
# Epoch: 1, Problem: 241.
# Epoch: 1, Problem: 242.
# Epoch: 1, Problem: 243.
# Epoch: 1, Problem: 244.
# Epoch: 1, Problem: 245.
# Epoch: 1, Problem: 246.
# Epoch: 1, Problem: 247.
# Epoch: 1, Problem: 248.
# Epoch: 1, Problem: 249.
# Epoch: 1, Problem: 250.
# Epoch: 1, Problem: 251.
# Epoch: 1, Problem: 252.
# Epoch: 1, Problem: 253.
# Epoch: 1, Problem: 254.
# Epoch: 1, Problem: 255.
# Epoch: 1, Problem: 256.
# Epoch: 1, Problem: 257.
# Epoch: 1, Problem: 258.
# Epoch: 1, Problem: 259.
# Epoch: 1, Problem: 260.
# Epoch: 1, Problem: 261.
# Epoch: 1, Problem: 262.
# Epoch: 1, Problem: 263.
# Epoch: 1, Problem: 264.
# Epoch: 1, Problem: 265.
# Epoch: 1, Problem: 266.
# Epoch: 1, Problem: 267.
# Epoch: 1, Problem: 268.
# Epoch: 1, Problem: 269.
# Epoch: 1, Problem: 270.
# Epoch: 1, Problem: 271.
# Epoch: 1, Problem: 272.
# Epoch: 1, Problem: 273.
# Epoch: 1, Problem: 274.
# Epoch: 1, Problem: 275.
# Epoch: 1, Problem: 276.
# Epoch: 1, Problem: 277.
# Epoch: 1, Problem: 278.
# Epoch: 1, Problem: 279.
# Epoch: 1, Problem: 280.
# Epoch: 1, Problem: 281.
# Epoch: 1, Problem: 282.
# Epoch: 1, Problem: 283.
# Epoch: 1, Problem: 284.
# Epoch: 1, Problem: 285.
# Epoch: 1, Problem: 286.
# Epoch: 1, Problem: 287.
# Epoch: 1, Problem: 288.
# Epoch: 1, Problem: 289.
# Epoch: 1, Problem: 290.
# Epoch: 1, Problem: 291.
# Epoch: 1, Problem: 292.
# Epoch: 1, Problem: 293.
# Epoch: 1, Problem: 294.
# Epoch: 1, Problem: 295.
# Epoch: 1, Problem: 296.
# Epoch: 1, Problem: 297.
# Epoch: 1, Problem: 298.
# Epoch: 1, Problem: 299.
# Epoch: 1, Problem: 300.
# Epoch: 1, Problem: 301.
# Epoch: 1, Problem: 302.
# Epoch: 1, Problem: 303.
# Epoch: 1, Problem: 304.
# Epoch: 1, Problem: 305.
# Epoch: 1, Problem: 306.
# Epoch: 1, Problem: 307.
# Epoch: 1, Problem: 308.
# Epoch: 1, Problem: 309.
# Epoch: 1, Problem: 310.
# Epoch: 1, Problem: 311.
# Epoch: 1, Problem: 312.
# Epoch: 1, Problem: 313.
# Epoch: 1, Problem: 314.
# Epoch: 1, Problem: 315.
# Epoch: 1, Problem: 316.
# Epoch: 1, Problem: 317.
# Epoch: 1, Problem: 318.
# Epoch: 1, Problem: 319.
# Epoch: 1, Problem: 320.
# Epoch: 1, Problem: 321.
# Epoch: 1, Problem: 322.
# Epoch: 1, Problem: 323.
# Epoch: 1, Problem: 324.
# Epoch: 1, Problem: 325.
# Epoch: 1, Problem: 326.
# Epoch: 1, Problem: 327.
# Epoch: 1, Problem: 328.
# Epoch: 1, Problem: 329.
# Epoch: 1, Problem: 330.
# Epoch: 1, Problem: 331.
# Epoch: 1, Problem: 332.
# Epoch: 1, Problem: 333.
# Epoch: 1, Problem: 334.
# Epoch: 1, Problem: 335.
# Epoch: 1, Problem: 336.
# Epoch: 1, Problem: 337.
# Epoch: 1, Problem: 338.
# Epoch: 1, Problem: 339.
# Epoch: 1, Problem: 340.
# Epoch: 1, Problem: 341.
# Epoch: 1, Problem: 342.
# Epoch: 1, Problem: 343.
# Epoch: 1, Problem: 344.
# Epoch: 1, Problem: 345.
# Epoch: 1, Problem: 346.
# Epoch: 1, Problem: 347.
# Epoch: 1, Problem: 348.
# Epoch: 1, Problem: 349.
# Epoch: 1, Problem: 350.
# Epoch: 1, Problem: 351.
# Epoch: 1, Problem: 352.
# Epoch: 1, Problem: 353.
# Epoch: 1, Problem: 354.
# Epoch: 1, Problem: 355.
# Epoch: 1, Problem: 356.
# Epoch: 1, Problem: 357.
# Epoch: 1, Problem: 358.
# Epoch: 1, Problem: 359.
# Epoch: 1, Problem: 360.
# Epoch: 1, Problem: 361.
# Epoch: 1, Problem: 362.
# Epoch: 1, Problem: 363.
# Epoch: 1, Problem: 364.
# Epoch: 1, Problem: 365.
# Epoch: 1, Problem: 366.
# Epoch: 1, Problem: 367.
# Epoch: 1, Problem: 368.
# Epoch: 1, Problem: 369.
# Epoch: 1, Problem: 370.
# Epoch: 1, Problem: 371.
# Epoch: 1, Problem: 372.
# Epoch: 1, Problem: 373.
# Epoch: 1, Problem: 374.
# Epoch: 1, Problem: 375.
# Epoch: 1, Problem: 376.
# Epoch: 1, Problem: 377.
# Epoch: 1, Problem: 378.
# Epoch: 1, Problem: 379.
# Epoch: 1, Problem: 380.
# Epoch: 1, Problem: 381.
# Epoch: 1, Problem: 382.
# Epoch: 1, Problem: 383.
# Epoch: 1, Problem: 384.
# Epoch: 1, Problem: 385.
# Epoch: 1, Problem: 386.
# Epoch: 1, Problem: 387.
# Epoch: 1, Problem: 388.
# Epoch: 1, Problem: 389.
# Epoch: 1, Problem: 390.
# Epoch: 1, Problem: 391.
# Epoch: 1, Problem: 392.
# Epoch: 1, Problem: 393.
# Epoch: 1, Problem: 394.
# Epoch: 1, Problem: 395.
# Epoch: 1, Problem: 396.
# Epoch: 1, Problem: 397.
# Epoch: 1, Problem: 398.
# Epoch: 1, Problem: 399.
# Epoch: 1, Problem: 400.
# Epoch: 1, Problem: 401.
# Epoch: 1, Problem: 402.
# Epoch: 1, Problem: 403.
# Epoch: 1, Problem: 404.
# Epoch: 1, Problem: 405.
# Epoch: 1, Problem: 406.
# Epoch: 1, Problem: 407.
# Epoch: 1, Problem: 408.
# Epoch: 1, Problem: 409.
# Epoch: 1, Problem: 410.
# Epoch: 1, Problem: 411.
# Epoch: 1, Problem: 412.
# Epoch: 1, Problem: 413.
# Epoch: 1, Problem: 414.
# Epoch: 1, Problem: 415.
# Epoch: 1, Problem: 416.
# Epoch: 1, Problem: 417.
# Epoch: 1, Problem: 418.
# Epoch: 1, Problem: 419.
# Epoch: 1, Problem: 420.
# Epoch: 1, Problem: 421.
# Epoch: 1, Problem: 422.
# Epoch: 1, Problem: 423.
# Epoch: 1, Problem: 424.
# Epoch: 1, Problem: 425.
# Epoch: 1, Problem: 426.
# Epoch: 1, Problem: 427.
# Epoch: 1, Problem: 428.
# Epoch: 1, Problem: 429.
# Epoch: 1, Problem: 430.
# Epoch: 1, Problem: 431.
# Epoch: 1, Problem: 432.
# Epoch: 1, Problem: 433.
# Epoch: 1, Problem: 434.
# Epoch: 1, Problem: 435.
# Epoch: 1, Problem: 436.
# Epoch: 1, Problem: 437.
# Epoch: 1, Problem: 438.
# Epoch: 1, Problem: 439.
# Epoch: 1, Problem: 440.
# Epoch: 1, Problem: 441.
# Epoch: 1, Problem: 442.
# Epoch: 1, Problem: 443.
# Epoch: 1, Problem: 444.
# Epoch: 1, Problem: 445.
# Epoch: 1, Problem: 446.
# Epoch: 1, Problem: 447.
# Epoch: 1, Problem: 448.
# Epoch: 1, Problem: 449.
# Epoch: 1, Problem: 450.
# Epoch: 1, Problem: 451.
# Epoch: 1, Problem: 452.
# Epoch: 1, Problem: 453.
# Epoch: 1, Problem: 454.
# Epoch: 1, Problem: 455.
# Epoch: 1, Problem: 456.
# Epoch: 1, Problem: 457.
# Epoch: 1, Problem: 458.
# Epoch: 1, Problem: 459.
# Epoch: 1, Problem: 460.
# Epoch: 1, Problem: 461.
# Epoch: 1, Problem: 462.
# Epoch: 1, Problem: 463.
# Epoch: 1, Problem: 464.
# Epoch: 1, Problem: 465.
# Epoch: 1, Problem: 466.
# Epoch: 1, Problem: 467.
# Epoch: 1, Problem: 468.
# Epoch: 1, Problem: 469.
# Epoch: 1, Problem: 470.
# Epoch: 1, Problem: 471.
# Epoch: 1, Problem: 472.
# Epoch: 1, Problem: 473.
# Epoch: 1, Problem: 474.
# Epoch: 1, Problem: 475.
# Epoch: 1, Problem: 476.
# Epoch: 1, Problem: 477.
# Epoch: 1, Problem: 478.
# Epoch: 1, Problem: 479.
# Epoch: 1, Problem: 480.
# Epoch: 1, Problem: 481.
# Epoch: 1, Problem: 482.
# Epoch: 1, Problem: 483.
# Epoch: 1, Problem: 484.
# Epoch: 1, Problem: 485.
# Epoch: 1, Problem: 486.
# Epoch: 1, Problem: 487.
# Epoch: 1, Problem: 488.
# Epoch: 1, Problem: 489.
# Epoch: 1, Problem: 490.
# Epoch: 1, Problem: 491.
# Epoch: 1, Problem: 492.
# Epoch: 1, Problem: 493.
# Epoch: 1, Problem: 494.
# Epoch: 1, Problem: 495.
# Epoch: 1, Problem: 496.
# Epoch: 1, Problem: 497.
# Epoch: 1, Problem: 498.
# Epoch: 1, Problem: 499.
# Epoch: 1, Problem: 500.
# Epoch: 2, Problem: 1.
# Epoch: 2, Problem: 2.
# Epoch: 2, Problem: 3.
# Epoch: 2, Problem: 4.
# Epoch: 2, Problem: 5.
# Epoch: 2, Problem: 6.
# Epoch: 2, Problem: 7.
# Epoch: 2, Problem: 8.
# Epoch: 2, Problem: 9.
# Epoch: 2, Problem: 10.
# Epoch: 2, Problem: 11.
# Epoch: 2, Problem: 12.
# Epoch: 2, Problem: 13.
# Epoch: 2, Problem: 14.
# Epoch: 2, Problem: 15.
# Epoch: 2, Problem: 16.
# Epoch: 2, Problem: 17.
# Epoch: 2, Problem: 18.
# Epoch: 2, Problem: 19.
# Epoch: 2, Problem: 20.
# Epoch: 2, Problem: 21.
# Epoch: 2, Problem: 22.
# Epoch: 2, Problem: 23.
# Epoch: 2, Problem: 24.
# Epoch: 2, Problem: 25.
# Epoch: 2, Problem: 26.
# Epoch: 2, Problem: 27.
# Epoch: 2, Problem: 28.
# Epoch: 2, Problem: 29.
# Epoch: 2, Problem: 30.
# Epoch: 2, Problem: 31.
# Epoch: 2, Problem: 32.
# Epoch: 2, Problem: 33.
# Epoch: 2, Problem: 34.
# Epoch: 2, Problem: 35.
# Epoch: 2, Problem: 36.
# Epoch: 2, Problem: 37.
# Epoch: 2, Problem: 38.
# Epoch: 2, Problem: 39.
# Epoch: 2, Problem: 40.
# Epoch: 2, Problem: 41.
# Epoch: 2, Problem: 42.
# Epoch: 2, Problem: 43.
# Epoch: 2, Problem: 44.
# Epoch: 2, Problem: 45.
# Epoch: 2, Problem: 46.
# Epoch: 2, Problem: 47.
# Epoch: 2, Problem: 48.
# Epoch: 2, Problem: 49.
# Epoch: 2, Problem: 50.
# Epoch: 2, Problem: 51.
# Epoch: 2, Problem: 52.
# Epoch: 2, Problem: 53.
# Epoch: 2, Problem: 54.
# Epoch: 2, Problem: 55.
# Epoch: 2, Problem: 56.
# Epoch: 2, Problem: 57.
# Epoch: 2, Problem: 58.
# Epoch: 2, Problem: 59.
# Epoch: 2, Problem: 60.
# Epoch: 2, Problem: 61.
# Epoch: 2, Problem: 62.
# Epoch: 2, Problem: 63.
# Epoch: 2, Problem: 64.
# Epoch: 2, Problem: 65.
# Epoch: 2, Problem: 66.
# Epoch: 2, Problem: 67.
# Epoch: 2, Problem: 68.
# Epoch: 2, Problem: 69.
# Epoch: 2, Problem: 70.
# Epoch: 2, Problem: 71.
# Epoch: 2, Problem: 72.
# Epoch: 2, Problem: 73.
# Epoch: 2, Problem: 74.
# Epoch: 2, Problem: 75.
# Epoch: 2, Problem: 76.
# Epoch: 2, Problem: 77.
# Epoch: 2, Problem: 78.
# Epoch: 2, Problem: 79.
# Epoch: 2, Problem: 80.
# Epoch: 2, Problem: 81.
# Epoch: 2, Problem: 82.
# Epoch: 2, Problem: 83.
# Epoch: 2, Problem: 84.
# Epoch: 2, Problem: 85.
# Epoch: 2, Problem: 86.
# Epoch: 2, Problem: 87.
# Epoch: 2, Problem: 88.
# Epoch: 2, Problem: 89.
# Epoch: 2, Problem: 90.
# Epoch: 2, Problem: 91.
# Epoch: 2, Problem: 92.
# Epoch: 2, Problem: 93.
# Epoch: 2, Problem: 94.
# Epoch: 2, Problem: 95.
# Epoch: 2, Problem: 96.
# Epoch: 2, Problem: 97.
# Epoch: 2, Problem: 98.
# Epoch: 2, Problem: 99.
# Epoch: 2, Problem: 100.
# Epoch: 2, Problem: 101.
# Epoch: 2, Problem: 102.
# Epoch: 2, Problem: 103.
# Epoch: 2, Problem: 104.
# Epoch: 2, Problem: 105.
# Epoch: 2, Problem: 106.
# Epoch: 2, Problem: 107.
# Epoch: 2, Problem: 108.
# Epoch: 2, Problem: 109.
# Epoch: 2, Problem: 110.
# Epoch: 2, Problem: 111.
# Epoch: 2, Problem: 112.
# Epoch: 2, Problem: 113.
# Epoch: 2, Problem: 114.
# Epoch: 2, Problem: 115.
# Epoch: 2, Problem: 116.
# Epoch: 2, Problem: 117.
# Epoch: 2, Problem: 118.
# Epoch: 2, Problem: 119.
# Epoch: 2, Problem: 120.
# Epoch: 2, Problem: 121.
# Epoch: 2, Problem: 122.
# Epoch: 2, Problem: 123.
# Epoch: 2, Problem: 124.
# Epoch: 2, Problem: 125.
# Epoch: 2, Problem: 126.
# Epoch: 2, Problem: 127.
# Epoch: 2, Problem: 128.
# Epoch: 2, Problem: 129.
# Epoch: 2, Problem: 130.
# Epoch: 2, Problem: 131.
# Epoch: 2, Problem: 132.
# Epoch: 2, Problem: 133.
# Epoch: 2, Problem: 134.
# Epoch: 2, Problem: 135.
# Epoch: 2, Problem: 136.
# Epoch: 2, Problem: 137.
# Epoch: 2, Problem: 138.
# Epoch: 2, Problem: 139.
# Epoch: 2, Problem: 140.
# Epoch: 2, Problem: 141.
# Epoch: 2, Problem: 142.
# Epoch: 2, Problem: 143.
# Epoch: 2, Problem: 144.
# Epoch: 2, Problem: 145.
# Epoch: 2, Problem: 146.
# Epoch: 2, Problem: 147.
# Epoch: 2, Problem: 148.
# Epoch: 2, Problem: 149.
# Epoch: 2, Problem: 150.
# Epoch: 2, Problem: 151.
# Epoch: 2, Problem: 152.
# Epoch: 2, Problem: 153.
# Epoch: 2, Problem: 154.
# Epoch: 2, Problem: 155.
# Epoch: 2, Problem: 156.
# Epoch: 2, Problem: 157.
# Epoch: 2, Problem: 158.
# Epoch: 2, Problem: 159.
# Epoch: 2, Problem: 160.
# Epoch: 2, Problem: 161.
# Epoch: 2, Problem: 162.
# Epoch: 2, Problem: 163.
# Epoch: 2, Problem: 164.
# Epoch: 2, Problem: 165.
# Epoch: 2, Problem: 166.
# Epoch: 2, Problem: 167.
# Epoch: 2, Problem: 168.
# Epoch: 2, Problem: 169.
# Epoch: 2, Problem: 170.
# Epoch: 2, Problem: 171.
# Epoch: 2, Problem: 172.
# Epoch: 2, Problem: 173.
# Epoch: 2, Problem: 174.
# Epoch: 2, Problem: 175.
# Epoch: 2, Problem: 176.
# Epoch: 2, Problem: 177.
# Epoch: 2, Problem: 178.
# Epoch: 2, Problem: 179.
# Epoch: 2, Problem: 180.
# Epoch: 2, Problem: 181.
# Epoch: 2, Problem: 182.
# Epoch: 2, Problem: 183.
# Epoch: 2, Problem: 184.
# Epoch: 2, Problem: 185.
# Epoch: 2, Problem: 186.
# Epoch: 2, Problem: 187.
# Epoch: 2, Problem: 188.
# Epoch: 2, Problem: 189.
# Epoch: 2, Problem: 190.
# Epoch: 2, Problem: 191.
# Epoch: 2, Problem: 192.
# Epoch: 2, Problem: 193.
# Epoch: 2, Problem: 194.
# Epoch: 2, Problem: 195.
# Epoch: 2, Problem: 196.
# Epoch: 2, Problem: 197.
# Epoch: 2, Problem: 198.
# Epoch: 2, Problem: 199.
# Epoch: 2, Problem: 200.
# Epoch: 2, Problem: 201.
# Epoch: 2, Problem: 202.
# Epoch: 2, Problem: 203.
# Epoch: 2, Problem: 204.
# Epoch: 2, Problem: 205.
# Epoch: 2, Problem: 206.
# Epoch: 2, Problem: 207.
# Epoch: 2, Problem: 208.
# Epoch: 2, Problem: 209.
# Epoch: 2, Problem: 210.
# Epoch: 2, Problem: 211.
# Epoch: 2, Problem: 212.
# Epoch: 2, Problem: 213.
# Epoch: 2, Problem: 214.
# Epoch: 2, Problem: 215.
# Epoch: 2, Problem: 216.
# Epoch: 2, Problem: 217.
# Epoch: 2, Problem: 218.
# Epoch: 2, Problem: 219.
# Epoch: 2, Problem: 220.
# Epoch: 2, Problem: 221.
# Epoch: 2, Problem: 222.
# Epoch: 2, Problem: 223.
# Epoch: 2, Problem: 224.
# Epoch: 2, Problem: 225.
# Epoch: 2, Problem: 226.
# Epoch: 2, Problem: 227.
# Epoch: 2, Problem: 228.
# Epoch: 2, Problem: 229.
# Epoch: 2, Problem: 230.
# Epoch: 2, Problem: 231.
# Epoch: 2, Problem: 232.
# Epoch: 2, Problem: 233.
# Epoch: 2, Problem: 234.
# Epoch: 2, Problem: 235.
# Epoch: 2, Problem: 236.
# Epoch: 2, Problem: 237.
# Epoch: 2, Problem: 238.
# Epoch: 2, Problem: 239.
# Epoch: 2, Problem: 240.
# Epoch: 2, Problem: 241.
# Epoch: 2, Problem: 242.
# Epoch: 2, Problem: 243.
# Epoch: 2, Problem: 244.
# Epoch: 2, Problem: 245.
# Epoch: 2, Problem: 246.
# Epoch: 2, Problem: 247.
# Epoch: 2, Problem: 248.
# Epoch: 2, Problem: 249.
# Epoch: 2, Problem: 250.
# Epoch: 2, Problem: 251.
# Epoch: 2, Problem: 252.
# Epoch: 2, Problem: 253.
# Epoch: 2, Problem: 254.
# Epoch: 2, Problem: 255.
# Epoch: 2, Problem: 256.
# Epoch: 2, Problem: 257.
# Epoch: 2, Problem: 258.
# Epoch: 2, Problem: 259.
# Epoch: 2, Problem: 260.
# Epoch: 2, Problem: 261.
# Epoch: 2, Problem: 262.
# Epoch: 2, Problem: 263.
# Epoch: 2, Problem: 264.
# Epoch: 2, Problem: 265.
# Epoch: 2, Problem: 266.
# Epoch: 2, Problem: 267.
# Epoch: 2, Problem: 268.
# Epoch: 2, Problem: 269.
# Epoch: 2, Problem: 270.
# Epoch: 2, Problem: 271.
# Epoch: 2, Problem: 272.
# Epoch: 2, Problem: 273.
# Epoch: 2, Problem: 274.
# Epoch: 2, Problem: 275.
# Epoch: 2, Problem: 276.
# Epoch: 2, Problem: 277.
# Epoch: 2, Problem: 278.
# Epoch: 2, Problem: 279.
# Epoch: 2, Problem: 280.
# Epoch: 2, Problem: 281.
# Epoch: 2, Problem: 282.
# Epoch: 2, Problem: 283.
# Epoch: 2, Problem: 284.
# Epoch: 2, Problem: 285.
# Epoch: 2, Problem: 286.
# Epoch: 2, Problem: 287.
# Epoch: 2, Problem: 288.
# Epoch: 2, Problem: 289.
# Epoch: 2, Problem: 290.
# Epoch: 2, Problem: 291.
# Epoch: 2, Problem: 292.
# Epoch: 2, Problem: 293.
# Epoch: 2, Problem: 294.
# Epoch: 2, Problem: 295.
# Epoch: 2, Problem: 296.
# Epoch: 2, Problem: 297.
# Epoch: 2, Problem: 298.
# Epoch: 2, Problem: 299.
# Epoch: 2, Problem: 300.
# Epoch: 2, Problem: 301.
# Epoch: 2, Problem: 302.
# Epoch: 2, Problem: 303.
# Epoch: 2, Problem: 304.
# Epoch: 2, Problem: 305.
# Epoch: 2, Problem: 306.
# Epoch: 2, Problem: 307.
# Epoch: 2, Problem: 308.
# Epoch: 2, Problem: 309.
# Epoch: 2, Problem: 310.
# Epoch: 2, Problem: 311.
# Epoch: 2, Problem: 312.
# Epoch: 2, Problem: 313.
# Epoch: 2, Problem: 314.
# Epoch: 2, Problem: 315.
# Epoch: 2, Problem: 316.
# Epoch: 2, Problem: 317.
# Epoch: 2, Problem: 318.
# Epoch: 2, Problem: 319.
# Epoch: 2, Problem: 320.
# Epoch: 2, Problem: 321.
# Epoch: 2, Problem: 322.
# Epoch: 2, Problem: 323.
# Epoch: 2, Problem: 324.
# Epoch: 2, Problem: 325.
# Epoch: 2, Problem: 326.
# Epoch: 2, Problem: 327.
# Epoch: 2, Problem: 328.
# Epoch: 2, Problem: 329.
# Epoch: 2, Problem: 330.
# Epoch: 2, Problem: 331.
# Epoch: 2, Problem: 332.
# Epoch: 2, Problem: 333.
# Epoch: 2, Problem: 334.
# Epoch: 2, Problem: 335.
# Epoch: 2, Problem: 336.
# Epoch: 2, Problem: 337.
# Epoch: 2, Problem: 338.
# Epoch: 2, Problem: 339.
# Epoch: 2, Problem: 340.
# Epoch: 2, Problem: 341.
# Epoch: 2, Problem: 342.
# Epoch: 2, Problem: 343.
# Epoch: 2, Problem: 344.
# Epoch: 2, Problem: 345.
# Epoch: 2, Problem: 346.
# Epoch: 2, Problem: 347.
# Epoch: 2, Problem: 348.
# Epoch: 2, Problem: 349.
# Epoch: 2, Problem: 350.
# Epoch: 2, Problem: 351.
# Epoch: 2, Problem: 352.
# Epoch: 2, Problem: 353.
# Epoch: 2, Problem: 354.
# Epoch: 2, Problem: 355.
# Epoch: 2, Problem: 356.
# Epoch: 2, Problem: 357.
# Epoch: 2, Problem: 358.
# Epoch: 2, Problem: 359.
# Epoch: 2, Problem: 360.
# Epoch: 2, Problem: 361.
# Epoch: 2, Problem: 362.
# Epoch: 2, Problem: 363.
# Epoch: 2, Problem: 364.
# Epoch: 2, Problem: 365.
# Epoch: 2, Problem: 366.
# Epoch: 2, Problem: 367.
# Epoch: 2, Problem: 368.
# Epoch: 2, Problem: 369.
# Epoch: 2, Problem: 370.
# Epoch: 2, Problem: 371.
# Epoch: 2, Problem: 372.
# Epoch: 2, Problem: 373.
# Epoch: 2, Problem: 374.
# Epoch: 2, Problem: 375.
# Epoch: 2, Problem: 376.
# Epoch: 2, Problem: 377.
# Epoch: 2, Problem: 378.
# Epoch: 2, Problem: 379.
# Epoch: 2, Problem: 380.
# Epoch: 2, Problem: 381.
# Epoch: 2, Problem: 382.
# Epoch: 2, Problem: 383.
# Epoch: 2, Problem: 384.
# Epoch: 2, Problem: 385.
# Epoch: 2, Problem: 386.
# Epoch: 2, Problem: 387.
# Epoch: 2, Problem: 388.
# Epoch: 2, Problem: 389.
# Epoch: 2, Problem: 390.
# Epoch: 2, Problem: 391.
# Epoch: 2, Problem: 392.
# Epoch: 2, Problem: 393.
# Epoch: 2, Problem: 394.
# Epoch: 2, Problem: 395.
# Epoch: 2, Problem: 396.
# Epoch: 2, Problem: 397.
# Epoch: 2, Problem: 398.
# Epoch: 2, Problem: 399.
# Epoch: 2, Problem: 400.
# Epoch: 2, Problem: 401.
# Epoch: 2, Problem: 402.
# Epoch: 2, Problem: 403.
# Epoch: 2, Problem: 404.
# Epoch: 2, Problem: 405.
# Epoch: 2, Problem: 406.
# Epoch: 2, Problem: 407.
# Epoch: 2, Problem: 408.
# Epoch: 2, Problem: 409.
# Epoch: 2, Problem: 410.
# Epoch: 2, Problem: 411.
# Epoch: 2, Problem: 412.
# Epoch: 2, Problem: 413.
# Epoch: 2, Problem: 414.
# Epoch: 2, Problem: 415.
# Epoch: 2, Problem: 416.
# Epoch: 2, Problem: 417.
# Epoch: 2, Problem: 418.
# Epoch: 2, Problem: 419.
# Epoch: 2, Problem: 420.
# Epoch: 2, Problem: 421.
# Epoch: 2, Problem: 422.
# Epoch: 2, Problem: 423.
# Epoch: 2, Problem: 424.
# Epoch: 2, Problem: 425.
# Epoch: 2, Problem: 426.
# Epoch: 2, Problem: 427.
# Epoch: 2, Problem: 428.
# Epoch: 2, Problem: 429.
# Epoch: 2, Problem: 430.
# Epoch: 2, Problem: 431.
# Epoch: 2, Problem: 432.
# Epoch: 2, Problem: 433.
# Epoch: 2, Problem: 434.
# Epoch: 2, Problem: 435.
# Epoch: 2, Problem: 436.
# Epoch: 2, Problem: 437.
# Epoch: 2, Problem: 438.
# Epoch: 2, Problem: 439.
# Epoch: 2, Problem: 440.
# Epoch: 2, Problem: 441.
# Epoch: 2, Problem: 442.
# Epoch: 2, Problem: 443.
# Epoch: 2, Problem: 444.
# Epoch: 2, Problem: 445.
# Epoch: 2, Problem: 446.
# Epoch: 2, Problem: 447.
# Epoch: 2, Problem: 448.
# Epoch: 2, Problem: 449.
# Epoch: 2, Problem: 450.
# Epoch: 2, Problem: 451.
# Epoch: 2, Problem: 452.
# Epoch: 2, Problem: 453.
# Epoch: 2, Problem: 454.
# Epoch: 2, Problem: 455.
# Epoch: 2, Problem: 456.
# Epoch: 2, Problem: 457.
# Epoch: 2, Problem: 458.
# Epoch: 2, Problem: 459.
# Epoch: 2, Problem: 460.
# Epoch: 2, Problem: 461.
# Epoch: 2, Problem: 462.
# Epoch: 2, Problem: 463.
# Epoch: 2, Problem: 464.
# Epoch: 2, Problem: 465.
# Epoch: 2, Problem: 466.
# Epoch: 2, Problem: 467.
# Epoch: 2, Problem: 468.
# Epoch: 2, Problem: 469.
# Epoch: 2, Problem: 470.
# Epoch: 2, Problem: 471.
# Epoch: 2, Problem: 472.
# Epoch: 2, Problem: 473.
# Epoch: 2, Problem: 474.
# Epoch: 2, Problem: 475.
# Epoch: 2, Problem: 476.
# Epoch: 2, Problem: 477.
# Epoch: 2, Problem: 478.
# Epoch: 2, Problem: 479.
# Epoch: 2, Problem: 480.
# Epoch: 2, Problem: 481.
# Epoch: 2, Problem: 482.
# Epoch: 2, Problem: 483.
# Epoch: 2, Problem: 484.
# Epoch: 2, Problem: 485.
# Epoch: 2, Problem: 486.
# Epoch: 2, Problem: 487.
# Epoch: 2, Problem: 488.
# Epoch: 2, Problem: 489.
# Epoch: 2, Problem: 490.
# Epoch: 2, Problem: 491.
# Epoch: 2, Problem: 492.
# Epoch: 2, Problem: 493.
# Epoch: 2, Problem: 494.
# Epoch: 2, Problem: 495.
# Epoch: 2, Problem: 496.
# Epoch: 2, Problem: 497.
# Epoch: 2, Problem: 498.
# Epoch: 2, Problem: 499.
# Epoch: 2, Problem: 500.
# Epoch: 3, Problem: 1.
# Epoch: 3, Problem: 2.
# Epoch: 3, Problem: 3.
# Epoch: 3, Problem: 4.
# Epoch: 3, Problem: 5.
# Epoch: 3, Problem: 6.
# Epoch: 3, Problem: 7.
# Epoch: 3, Problem: 8.
# Epoch: 3, Problem: 9.
# Epoch: 3, Problem: 10.
# Epoch: 3, Problem: 11.
# Epoch: 3, Problem: 12.
# Epoch: 3, Problem: 13.
# Epoch: 3, Problem: 14.
# Epoch: 3, Problem: 15.
# Epoch: 3, Problem: 16.
# Epoch: 3, Problem: 17.
# Epoch: 3, Problem: 18.
# Epoch: 3, Problem: 19.
# Epoch: 3, Problem: 20.
# Epoch: 3, Problem: 21.
# Epoch: 3, Problem: 22.
# Epoch: 3, Problem: 23.
# Epoch: 3, Problem: 24.
# Epoch: 3, Problem: 25.
# Epoch: 3, Problem: 26.
# Epoch: 3, Problem: 27.
# Epoch: 3, Problem: 28.
# Epoch: 3, Problem: 29.
# Epoch: 3, Problem: 30.
# Epoch: 3, Problem: 31.
# Epoch: 3, Problem: 32.
# Epoch: 3, Problem: 33.
# Epoch: 3, Problem: 34.
# Epoch: 3, Problem: 35.
# Epoch: 3, Problem: 36.
# Epoch: 3, Problem: 37.
# Epoch: 3, Problem: 38.
# Epoch: 3, Problem: 39.
# Epoch: 3, Problem: 40.
# Epoch: 3, Problem: 41.
# Epoch: 3, Problem: 42.
# Epoch: 3, Problem: 43.
# Epoch: 3, Problem: 44.
# Epoch: 3, Problem: 45.
# Epoch: 3, Problem: 46.
# Epoch: 3, Problem: 47.
# Epoch: 3, Problem: 48.
# Epoch: 3, Problem: 49.
# Epoch: 3, Problem: 50.
# Epoch: 3, Problem: 51.
# Epoch: 3, Problem: 52.
# Epoch: 3, Problem: 53.
# Epoch: 3, Problem: 54.
# Epoch: 3, Problem: 55.
# Epoch: 3, Problem: 56.
# Epoch: 3, Problem: 57.
# Epoch: 3, Problem: 58.
# Epoch: 3, Problem: 59.
# Epoch: 3, Problem: 60.
# Epoch: 3, Problem: 61.
# Epoch: 3, Problem: 62.
# Epoch: 3, Problem: 63.
# Epoch: 3, Problem: 64.
# Epoch: 3, Problem: 65.
# Epoch: 3, Problem: 66.
# Epoch: 3, Problem: 67.
# Epoch: 3, Problem: 68.
# Epoch: 3, Problem: 69.
# Epoch: 3, Problem: 70.
# Epoch: 3, Problem: 71.
# Epoch: 3, Problem: 72.
# Epoch: 3, Problem: 73.
# Epoch: 3, Problem: 74.
# Epoch: 3, Problem: 75.
# Epoch: 3, Problem: 76.
# Epoch: 3, Problem: 77.
# Epoch: 3, Problem: 78.
# Epoch: 3, Problem: 79.
# Epoch: 3, Problem: 80.
# Epoch: 3, Problem: 81.
# Epoch: 3, Problem: 82.
# Epoch: 3, Problem: 83.
# Epoch: 3, Problem: 84.
# Epoch: 3, Problem: 85.
# Epoch: 3, Problem: 86.
# Epoch: 3, Problem: 87.
# Epoch: 3, Problem: 88.
# Epoch: 3, Problem: 89.
# Epoch: 3, Problem: 90.
# Epoch: 3, Problem: 91.
# Epoch: 3, Problem: 92.
# Epoch: 3, Problem: 93.
# Epoch: 3, Problem: 94.
# Epoch: 3, Problem: 95.
# Epoch: 3, Problem: 96.
# Epoch: 3, Problem: 97.
# Epoch: 3, Problem: 98.
# Epoch: 3, Problem: 99.
# Epoch: 3, Problem: 100.
# Epoch: 3, Problem: 101.
# Epoch: 3, Problem: 102.
# Epoch: 3, Problem: 103.
# Epoch: 3, Problem: 104.
# Epoch: 3, Problem: 105.
# Epoch: 3, Problem: 106.
# Epoch: 3, Problem: 107.
# Epoch: 3, Problem: 108.
# Epoch: 3, Problem: 109.
# Epoch: 3, Problem: 110.
# Epoch: 3, Problem: 111.
# Epoch: 3, Problem: 112.
# Epoch: 3, Problem: 113.
# Epoch: 3, Problem: 114.
# Epoch: 3, Problem: 115.
# Epoch: 3, Problem: 116.
# Epoch: 3, Problem: 117.
# Epoch: 3, Problem: 118.
# Epoch: 3, Problem: 119.
# Epoch: 3, Problem: 120.
# Epoch: 3, Problem: 121.
# Epoch: 3, Problem: 122.
# Epoch: 3, Problem: 123.
# Epoch: 3, Problem: 124.
# Epoch: 3, Problem: 125.
# Epoch: 3, Problem: 126.
# Epoch: 3, Problem: 127.
# Epoch: 3, Problem: 128.
# Epoch: 3, Problem: 129.
# Epoch: 3, Problem: 130.
# Epoch: 3, Problem: 131.
# Epoch: 3, Problem: 132.
# Epoch: 3, Problem: 133.
# Epoch: 3, Problem: 134.
# Epoch: 3, Problem: 135.
# Epoch: 3, Problem: 136.
# Epoch: 3, Problem: 137.
# Epoch: 3, Problem: 138.
# Epoch: 3, Problem: 139.
# Epoch: 3, Problem: 140.
# Epoch: 3, Problem: 141.
# Epoch: 3, Problem: 142.
# Epoch: 3, Problem: 143.
# Epoch: 3, Problem: 144.
# Epoch: 3, Problem: 145.
# Epoch: 3, Problem: 146.
# Epoch: 3, Problem: 147.
# Epoch: 3, Problem: 148.
# Epoch: 3, Problem: 149.
# Epoch: 3, Problem: 150.
# Epoch: 3, Problem: 151.
# Epoch: 3, Problem: 152.
# Epoch: 3, Problem: 153.
# Epoch: 3, Problem: 154.
# Epoch: 3, Problem: 155.
# Epoch: 3, Problem: 156.
# Epoch: 3, Problem: 157.
# Epoch: 3, Problem: 158.
# Epoch: 3, Problem: 159.
# Epoch: 3, Problem: 160.
# Epoch: 3, Problem: 161.
# Epoch: 3, Problem: 162.
# Epoch: 3, Problem: 163.
# Epoch: 3, Problem: 164.
# Epoch: 3, Problem: 165.
# Epoch: 3, Problem: 166.
# Epoch: 3, Problem: 167.
# Epoch: 3, Problem: 168.
# Epoch: 3, Problem: 169.
# Epoch: 3, Problem: 170.
# Epoch: 3, Problem: 171.
# Epoch: 3, Problem: 172.
# Epoch: 3, Problem: 173.
# Epoch: 3, Problem: 174.
# Epoch: 3, Problem: 175.
# Epoch: 3, Problem: 176.
# Epoch: 3, Problem: 177.
# Epoch: 3, Problem: 178.
# Epoch: 3, Problem: 179.
# Epoch: 3, Problem: 180.
# Epoch: 3, Problem: 181.
# Epoch: 3, Problem: 182.
# Epoch: 3, Problem: 183.
# Epoch: 3, Problem: 184.
# Epoch: 3, Problem: 185.
# Epoch: 3, Problem: 186.
# Epoch: 3, Problem: 187.
# Epoch: 3, Problem: 188.
# Epoch: 3, Problem: 189.
# Epoch: 3, Problem: 190.
# Epoch: 3, Problem: 191.
# Epoch: 3, Problem: 192.
# Epoch: 3, Problem: 193.
# Epoch: 3, Problem: 194.
# Epoch: 3, Problem: 195.
# Epoch: 3, Problem: 196.
# Epoch: 3, Problem: 197.
# Epoch: 3, Problem: 198.
# Epoch: 3, Problem: 199.
# Epoch: 3, Problem: 200.
# Epoch: 3, Problem: 201.
# Epoch: 3, Problem: 202.
# Epoch: 3, Problem: 203.
# Epoch: 3, Problem: 204.
# Epoch: 3, Problem: 205.
# Epoch: 3, Problem: 206.
# Epoch: 3, Problem: 207.
# Epoch: 3, Problem: 208.
# Epoch: 3, Problem: 209.
# Epoch: 3, Problem: 210.
# Epoch: 3, Problem: 211.
# Epoch: 3, Problem: 212.
# Epoch: 3, Problem: 213.
# Epoch: 3, Problem: 214.
# Epoch: 3, Problem: 215.
# Epoch: 3, Problem: 216.
# Epoch: 3, Problem: 217.
# Epoch: 3, Problem: 218.
# Epoch: 3, Problem: 219.
# Epoch: 3, Problem: 220.
# Epoch: 3, Problem: 221.
# Epoch: 3, Problem: 222.
# Epoch: 3, Problem: 223.
# Epoch: 3, Problem: 224.
# Epoch: 3, Problem: 225.
# Epoch: 3, Problem: 226.
# Epoch: 3, Problem: 227.
# Epoch: 3, Problem: 228.
# Epoch: 3, Problem: 229.
# Epoch: 3, Problem: 230.
# Epoch: 3, Problem: 231.
# Epoch: 3, Problem: 232.
# Epoch: 3, Problem: 233.
# Epoch: 3, Problem: 234.
# Epoch: 3, Problem: 235.
# Epoch: 3, Problem: 236.
# Epoch: 3, Problem: 237.
# Epoch: 3, Problem: 238.
# Epoch: 3, Problem: 239.
# Epoch: 3, Problem: 240.
# Epoch: 3, Problem: 241.
# Epoch: 3, Problem: 242.
# Epoch: 3, Problem: 243.
# Epoch: 3, Problem: 244.
# Epoch: 3, Problem: 245.
# Epoch: 3, Problem: 246.
# Epoch: 3, Problem: 247.
# Epoch: 3, Problem: 248.
# Epoch: 3, Problem: 249.
# Epoch: 3, Problem: 250.
# Epoch: 3, Problem: 251.
# Epoch: 3, Problem: 252.
# Epoch: 3, Problem: 253.
# Epoch: 3, Problem: 254.
# Epoch: 3, Problem: 255.
# Epoch: 3, Problem: 256.
# Epoch: 3, Problem: 257.
# Epoch: 3, Problem: 258.
# Epoch: 3, Problem: 259.
# Epoch: 3, Problem: 260.
# Epoch: 3, Problem: 261.
# Epoch: 3, Problem: 262.
# Epoch: 3, Problem: 263.
# Epoch: 3, Problem: 264.
# Epoch: 3, Problem: 265.
# Epoch: 3, Problem: 266.
# Epoch: 3, Problem: 267.
# Epoch: 3, Problem: 268.
# Epoch: 3, Problem: 269.
# Epoch: 3, Problem: 270.
# Epoch: 3, Problem: 271.
# Epoch: 3, Problem: 272.
# Epoch: 3, Problem: 273.
# Epoch: 3, Problem: 274.
# Epoch: 3, Problem: 275.
# Epoch: 3, Problem: 276.
# Epoch: 3, Problem: 277.
# Epoch: 3, Problem: 278.
# Epoch: 3, Problem: 279.
# Epoch: 3, Problem: 280.
# Epoch: 3, Problem: 281.
# Epoch: 3, Problem: 282.
# Epoch: 3, Problem: 283.
# Epoch: 3, Problem: 284.
# Epoch: 3, Problem: 285.
# Epoch: 3, Problem: 286.
# Epoch: 3, Problem: 287.
# Epoch: 3, Problem: 288.
# Epoch: 3, Problem: 289.
# Epoch: 3, Problem: 290.
# Epoch: 3, Problem: 291.
# Epoch: 3, Problem: 292.
# Epoch: 3, Problem: 293.
# Epoch: 3, Problem: 294.
# Epoch: 3, Problem: 295.
# Epoch: 3, Problem: 296.
# Epoch: 3, Problem: 297.
# Epoch: 3, Problem: 298.
# Epoch: 3, Problem: 299.
# Epoch: 3, Problem: 300.
# Epoch: 3, Problem: 301.
# Epoch: 3, Problem: 302.
# Epoch: 3, Problem: 303.
# Epoch: 3, Problem: 304.
# Epoch: 3, Problem: 305.
# Epoch: 3, Problem: 306.
# Epoch: 3, Problem: 307.
# Epoch: 3, Problem: 308.
# Epoch: 3, Problem: 309.
# Epoch: 3, Problem: 310.
# Epoch: 3, Problem: 311.
# Epoch: 3, Problem: 312.
# Epoch: 3, Problem: 313.
# Epoch: 3, Problem: 314.
# Epoch: 3, Problem: 315.
# Epoch: 3, Problem: 316.
# Epoch: 3, Problem: 317.
# Epoch: 3, Problem: 318.
# Epoch: 3, Problem: 319.
# Epoch: 3, Problem: 320.
# Epoch: 3, Problem: 321.
# Epoch: 3, Problem: 322.
# Epoch: 3, Problem: 323.
# Epoch: 3, Problem: 324.
# Epoch: 3, Problem: 325.
# Epoch: 3, Problem: 326.
# Epoch: 3, Problem: 327.
# Epoch: 3, Problem: 328.
# Epoch: 3, Problem: 329.
# Epoch: 3, Problem: 330.
# Epoch: 3, Problem: 331.
# Epoch: 3, Problem: 332.
# Epoch: 3, Problem: 333.
# Epoch: 3, Problem: 334.
# Epoch: 3, Problem: 335.
# Epoch: 3, Problem: 336.
# Epoch: 3, Problem: 337.
# Epoch: 3, Problem: 338.
# Epoch: 3, Problem: 339.
# Epoch: 3, Problem: 340.
# Epoch: 3, Problem: 341.
# Epoch: 3, Problem: 342.
# Epoch: 3, Problem: 343.
# Epoch: 3, Problem: 344.
# Epoch: 3, Problem: 345.
# Epoch: 3, Problem: 346.
# Epoch: 3, Problem: 347.
# Epoch: 3, Problem: 348.
# Epoch: 3, Problem: 349.
# Epoch: 3, Problem: 350.
# Epoch: 3, Problem: 351.
# Epoch: 3, Problem: 352.
# Epoch: 3, Problem: 353.
# Epoch: 3, Problem: 354.
# Epoch: 3, Problem: 355.
# Epoch: 3, Problem: 356.
# Epoch: 3, Problem: 357.
# Epoch: 3, Problem: 358.
# Epoch: 3, Problem: 359.
# Epoch: 3, Problem: 360.
# Epoch: 3, Problem: 361.
# Epoch: 3, Problem: 362.
# Epoch: 3, Problem: 363.
# Epoch: 3, Problem: 364.
# Epoch: 3, Problem: 365.
# Epoch: 3, Problem: 366.
# Epoch: 3, Problem: 367.
# Epoch: 3, Problem: 368.
# Epoch: 3, Problem: 369.
# Epoch: 3, Problem: 370.
# Epoch: 3, Problem: 371.
# Epoch: 3, Problem: 372.
# Epoch: 3, Problem: 373.
# Epoch: 3, Problem: 374.
# Epoch: 3, Problem: 375.
# Epoch: 3, Problem: 376.
# Epoch: 3, Problem: 377.
# Epoch: 3, Problem: 378.
# Epoch: 3, Problem: 379.
# Epoch: 3, Problem: 380.
# Epoch: 3, Problem: 381.
# Epoch: 3, Problem: 382.
# Epoch: 3, Problem: 383.
# Epoch: 3, Problem: 384.
# Epoch: 3, Problem: 385.
# Epoch: 3, Problem: 386.
# Epoch: 3, Problem: 387.
# Epoch: 3, Problem: 388.
# Epoch: 3, Problem: 389.
# Epoch: 3, Problem: 390.
# Epoch: 3, Problem: 391.
# Epoch: 3, Problem: 392.
# Epoch: 3, Problem: 393.
# Epoch: 3, Problem: 394.
# Epoch: 3, Problem: 395.
# Epoch: 3, Problem: 396.
# Epoch: 3, Problem: 397.
# Epoch: 3, Problem: 398.
# Epoch: 3, Problem: 399.
# Epoch: 3, Problem: 400.
# Epoch: 3, Problem: 401.
# Epoch: 3, Problem: 402.
# Epoch: 3, Problem: 403.
# Epoch: 3, Problem: 404.
# Epoch: 3, Problem: 405.
# Epoch: 3, Problem: 406.
# Epoch: 3, Problem: 407.
# Epoch: 3, Problem: 408.
# Epoch: 3, Problem: 409.
# Epoch: 3, Problem: 410.
# Epoch: 3, Problem: 411.
# Epoch: 3, Problem: 412.
# Epoch: 3, Problem: 413.
# Epoch: 3, Problem: 414.
# Epoch: 3, Problem: 415.
# Epoch: 3, Problem: 416.
# Epoch: 3, Problem: 417.
# Epoch: 3, Problem: 418.
# Epoch: 3, Problem: 419.
# Epoch: 3, Problem: 420.
# Epoch: 3, Problem: 421.
# Epoch: 3, Problem: 422.
# Epoch: 3, Problem: 423.
# Epoch: 3, Problem: 424.
# Epoch: 3, Problem: 425.
# Epoch: 3, Problem: 426.
# Epoch: 3, Problem: 427.
# Epoch: 3, Problem: 428.
# Epoch: 3, Problem: 429.
# Epoch: 3, Problem: 430.
# Epoch: 3, Problem: 431.
# Epoch: 3, Problem: 432.
# Epoch: 3, Problem: 433.
# Epoch: 3, Problem: 434.
# Epoch: 3, Problem: 435.
# Epoch: 3, Problem: 436.
# Epoch: 3, Problem: 437.
# Epoch: 3, Problem: 438.
# Epoch: 3, Problem: 439.
# Epoch: 3, Problem: 440.
# Epoch: 3, Problem: 441.
# Epoch: 3, Problem: 442.
# Epoch: 3, Problem: 443.
# Epoch: 3, Problem: 444.
# Epoch: 3, Problem: 445.
# Epoch: 3, Problem: 446.
# Epoch: 3, Problem: 447.
# Epoch: 3, Problem: 448.
# Epoch: 3, Problem: 449.
# Epoch: 3, Problem: 450.
# Epoch: 3, Problem: 451.
# Epoch: 3, Problem: 452.
# Epoch: 3, Problem: 453.
# Epoch: 3, Problem: 454.
# Epoch: 3, Problem: 455.
# Epoch: 3, Problem: 456.
# Epoch: 3, Problem: 457.
# Epoch: 3, Problem: 458.
# Epoch: 3, Problem: 459.
# Epoch: 3, Problem: 460.
# Epoch: 3, Problem: 461.
# Epoch: 3, Problem: 462.
# Epoch: 3, Problem: 463.
# Epoch: 3, Problem: 464.
# Epoch: 3, Problem: 465.
# Epoch: 3, Problem: 466.
# Epoch: 3, Problem: 467.
# Epoch: 3, Problem: 468.
# Epoch: 3, Problem: 469.
# Epoch: 3, Problem: 470.
# Epoch: 3, Problem: 471.
# Epoch: 3, Problem: 472.
# Epoch: 3, Problem: 473.
# Epoch: 3, Problem: 474.
# Epoch: 3, Problem: 475.
# Epoch: 3, Problem: 476.
# Epoch: 3, Problem: 477.
# Epoch: 3, Problem: 478.
# Epoch: 3, Problem: 479.
# Epoch: 3, Problem: 480.
# Epoch: 3, Problem: 481.
# Epoch: 3, Problem: 482.
# Epoch: 3, Problem: 483.
# Epoch: 3, Problem: 484.
# Epoch: 3, Problem: 485.
# Epoch: 3, Problem: 486.
# Epoch: 3, Problem: 487.
# Epoch: 3, Problem: 488.
# Epoch: 3, Problem: 489.
# Epoch: 3, Problem: 490.
# Epoch: 3, Problem: 491.
# Epoch: 3, Problem: 492.
# Epoch: 3, Problem: 493.
# Epoch: 3, Problem: 494.
# Epoch: 3, Problem: 495.
# Epoch: 3, Problem: 496.
# Epoch: 3, Problem: 497.
# Epoch: 3, Problem: 498.
# Epoch: 3, Problem: 499.
# Epoch: 3, Problem: 500.
# Epoch: 4, Problem: 1.
# Epoch: 4, Problem: 2.
# Epoch: 4, Problem: 3.
# Epoch: 4, Problem: 4.
# Epoch: 4, Problem: 5.
# Epoch: 4, Problem: 6.
# Epoch: 4, Problem: 7.
# Epoch: 4, Problem: 8.
# Epoch: 4, Problem: 9.
# Epoch: 4, Problem: 10.
# Epoch: 4, Problem: 11.
# Epoch: 4, Problem: 12.
# Epoch: 4, Problem: 13.
# Epoch: 4, Problem: 14.
# Epoch: 4, Problem: 15.
# Epoch: 4, Problem: 16.
# Epoch: 4, Problem: 17.
# Epoch: 4, Problem: 18.
# Epoch: 4, Problem: 19.
# Epoch: 4, Problem: 20.
# Epoch: 4, Problem: 21.
# Epoch: 4, Problem: 22.
# Epoch: 4, Problem: 23.
# Epoch: 4, Problem: 24.
# Epoch: 4, Problem: 25.
# Epoch: 4, Problem: 26.
# Epoch: 4, Problem: 27.
# Epoch: 4, Problem: 28.
# Epoch: 4, Problem: 29.
# Epoch: 4, Problem: 30.
# Epoch: 4, Problem: 31.
# Epoch: 4, Problem: 32.
# Epoch: 4, Problem: 33.
# Epoch: 4, Problem: 34.
# Epoch: 4, Problem: 35.
# Epoch: 4, Problem: 36.
# Epoch: 4, Problem: 37.
# Epoch: 4, Problem: 38.
# Epoch: 4, Problem: 39.
# Epoch: 4, Problem: 40.
# Epoch: 4, Problem: 41.
# Epoch: 4, Problem: 42.
# Epoch: 4, Problem: 43.
# Epoch: 4, Problem: 44.
# Epoch: 4, Problem: 45.
# Epoch: 4, Problem: 46.
# Epoch: 4, Problem: 47.
# Epoch: 4, Problem: 48.
# Epoch: 4, Problem: 49.
# Epoch: 4, Problem: 50.
# Epoch: 4, Problem: 51.
# Epoch: 4, Problem: 52.
# Epoch: 4, Problem: 53.
# Epoch: 4, Problem: 54.
# Epoch: 4, Problem: 55.
# Epoch: 4, Problem: 56.
# Epoch: 4, Problem: 57.
# Epoch: 4, Problem: 58.
# Epoch: 4, Problem: 59.
# Epoch: 4, Problem: 60.
# Epoch: 4, Problem: 61.
# Epoch: 4, Problem: 62.
# Epoch: 4, Problem: 63.
# Epoch: 4, Problem: 64.
# Epoch: 4, Problem: 65.
# Epoch: 4, Problem: 66.
# Epoch: 4, Problem: 67.
# Epoch: 4, Problem: 68.
# Epoch: 4, Problem: 69.
# Epoch: 4, Problem: 70.
# Epoch: 4, Problem: 71.
# Epoch: 4, Problem: 72.
# Epoch: 4, Problem: 73.
# Epoch: 4, Problem: 74.
# Epoch: 4, Problem: 75.
# Epoch: 4, Problem: 76.
# Epoch: 4, Problem: 77.
# Epoch: 4, Problem: 78.
# Epoch: 4, Problem: 79.
# Epoch: 4, Problem: 80.
# Epoch: 4, Problem: 81.
# Epoch: 4, Problem: 82.
# Epoch: 4, Problem: 83.
# Epoch: 4, Problem: 84.
# Epoch: 4, Problem: 85.
# Epoch: 4, Problem: 86.
# Epoch: 4, Problem: 87.
# Epoch: 4, Problem: 88.
# Epoch: 4, Problem: 89.
# Epoch: 4, Problem: 90.
# Epoch: 4, Problem: 91.
# Epoch: 4, Problem: 92.
# Epoch: 4, Problem: 93.
# Epoch: 4, Problem: 94.
# Epoch: 4, Problem: 95.
# Epoch: 4, Problem: 96.
# Epoch: 4, Problem: 97.
# Epoch: 4, Problem: 98.
# Epoch: 4, Problem: 99.
# Epoch: 4, Problem: 100.
# Epoch: 4, Problem: 101.
# Epoch: 4, Problem: 102.
# Epoch: 4, Problem: 103.
# Epoch: 4, Problem: 104.
# Epoch: 4, Problem: 105.
# Epoch: 4, Problem: 106.
# Epoch: 4, Problem: 107.
# Epoch: 4, Problem: 108.
# Epoch: 4, Problem: 109.
# Epoch: 4, Problem: 110.
# Epoch: 4, Problem: 111.
# Epoch: 4, Problem: 112.
# Epoch: 4, Problem: 113.
# Epoch: 4, Problem: 114.
# Epoch: 4, Problem: 115.
# Epoch: 4, Problem: 116.
# Epoch: 4, Problem: 117.
# Epoch: 4, Problem: 118.
# Epoch: 4, Problem: 119.
# Epoch: 4, Problem: 120.
# Epoch: 4, Problem: 121.
# Epoch: 4, Problem: 122.
# Epoch: 4, Problem: 123.
# Epoch: 4, Problem: 124.
# Epoch: 4, Problem: 125.
# Epoch: 4, Problem: 126.
# Epoch: 4, Problem: 127.
# Epoch: 4, Problem: 128.
# Epoch: 4, Problem: 129.
# Epoch: 4, Problem: 130.
# Epoch: 4, Problem: 131.
# Epoch: 4, Problem: 132.
# Epoch: 4, Problem: 133.
# Epoch: 4, Problem: 134.
# Epoch: 4, Problem: 135.
# Epoch: 4, Problem: 136.
# Epoch: 4, Problem: 137.
# Epoch: 4, Problem: 138.
# Epoch: 4, Problem: 139.
# Epoch: 4, Problem: 140.
# Epoch: 4, Problem: 141.
# Epoch: 4, Problem: 142.
# Epoch: 4, Problem: 143.
# Epoch: 4, Problem: 144.
# Epoch: 4, Problem: 145.
# Epoch: 4, Problem: 146.
# Epoch: 4, Problem: 147.
# Epoch: 4, Problem: 148.
# Epoch: 4, Problem: 149.
# Epoch: 4, Problem: 150.
# Epoch: 4, Problem: 151.
# Epoch: 4, Problem: 152.
# Epoch: 4, Problem: 153.
# Epoch: 4, Problem: 154.
# Epoch: 4, Problem: 155.
# Epoch: 4, Problem: 156.
# Epoch: 4, Problem: 157.
# Epoch: 4, Problem: 158.
# Epoch: 4, Problem: 159.
# Epoch: 4, Problem: 160.
# Epoch: 4, Problem: 161.
# Epoch: 4, Problem: 162.
# Epoch: 4, Problem: 163.
# Epoch: 4, Problem: 164.
# Epoch: 4, Problem: 165.
# Epoch: 4, Problem: 166.
# Epoch: 4, Problem: 167.
# Epoch: 4, Problem: 168.
# Epoch: 4, Problem: 169.
# Epoch: 4, Problem: 170.
# Epoch: 4, Problem: 171.
# Epoch: 4, Problem: 172.
# Epoch: 4, Problem: 173.
# Epoch: 4, Problem: 174.
# Epoch: 4, Problem: 175.
# Epoch: 4, Problem: 176.
# Epoch: 4, Problem: 177.
# Epoch: 4, Problem: 178.
# Epoch: 4, Problem: 179.
# Epoch: 4, Problem: 180.
# Epoch: 4, Problem: 181.
# Epoch: 4, Problem: 182.
# Epoch: 4, Problem: 183.
# Epoch: 4, Problem: 184.
# Epoch: 4, Problem: 185.
# Epoch: 4, Problem: 186.
# Epoch: 4, Problem: 187.
# Epoch: 4, Problem: 188.
# Epoch: 4, Problem: 189.
# Epoch: 4, Problem: 190.
# Epoch: 4, Problem: 191.
# Epoch: 4, Problem: 192.
# Epoch: 4, Problem: 193.
# Epoch: 4, Problem: 194.
# Epoch: 4, Problem: 195.
# Epoch: 4, Problem: 196.
# Epoch: 4, Problem: 197.
# Epoch: 4, Problem: 198.
# Epoch: 4, Problem: 199.
# Epoch: 4, Problem: 200.
# Epoch: 4, Problem: 201.
# Epoch: 4, Problem: 202.
# Epoch: 4, Problem: 203.
# Epoch: 4, Problem: 204.
# Epoch: 4, Problem: 205.
# Epoch: 4, Problem: 206.
# Epoch: 4, Problem: 207.
# Epoch: 4, Problem: 208.
# Epoch: 4, Problem: 209.
# Epoch: 4, Problem: 210.
# Epoch: 4, Problem: 211.
# Epoch: 4, Problem: 212.
# Epoch: 4, Problem: 213.
# Epoch: 4, Problem: 214.
# Epoch: 4, Problem: 215.
# Epoch: 4, Problem: 216.
# Epoch: 4, Problem: 217.
# Epoch: 4, Problem: 218.
# Epoch: 4, Problem: 219.
# Epoch: 4, Problem: 220.
# Epoch: 4, Problem: 221.
# Epoch: 4, Problem: 222.
# Epoch: 4, Problem: 223.
# Epoch: 4, Problem: 224.
# Epoch: 4, Problem: 225.
# Epoch: 4, Problem: 226.
# Epoch: 4, Problem: 227.
# Epoch: 4, Problem: 228.
# Epoch: 4, Problem: 229.
# Epoch: 4, Problem: 230.
# Epoch: 4, Problem: 231.
# Epoch: 4, Problem: 232.
# Epoch: 4, Problem: 233.
# Epoch: 4, Problem: 234.
# Epoch: 4, Problem: 235.
# Epoch: 4, Problem: 236.
# Epoch: 4, Problem: 237.
# Epoch: 4, Problem: 238.
# Epoch: 4, Problem: 239.
# Epoch: 4, Problem: 240.
# Epoch: 4, Problem: 241.
# Epoch: 4, Problem: 242.
# Epoch: 4, Problem: 243.
# Epoch: 4, Problem: 244.
# Epoch: 4, Problem: 245.
# Epoch: 4, Problem: 246.
# Epoch: 4, Problem: 247.
# Epoch: 4, Problem: 248.
# Epoch: 4, Problem: 249.
# Epoch: 4, Problem: 250.
# Epoch: 4, Problem: 251.
# Epoch: 4, Problem: 252.
# Epoch: 4, Problem: 253.
# Epoch: 4, Problem: 254.
# Epoch: 4, Problem: 255.
# Epoch: 4, Problem: 256.
# Epoch: 4, Problem: 257.
# Epoch: 4, Problem: 258.
# Epoch: 4, Problem: 259.
# Epoch: 4, Problem: 260.
# Epoch: 4, Problem: 261.
# Epoch: 4, Problem: 262.
# Epoch: 4, Problem: 263.
# Epoch: 4, Problem: 264.
# Epoch: 4, Problem: 265.
# Epoch: 4, Problem: 266.
# Epoch: 4, Problem: 267.
# Epoch: 4, Problem: 268.
# Epoch: 4, Problem: 269.
# Epoch: 4, Problem: 270.
# Epoch: 4, Problem: 271.
# Epoch: 4, Problem: 272.
# Epoch: 4, Problem: 273.
# Epoch: 4, Problem: 274.
# Epoch: 4, Problem: 275.
# Epoch: 4, Problem: 276.
# Epoch: 4, Problem: 277.
# Epoch: 4, Problem: 278.
# Epoch: 4, Problem: 279.
# Epoch: 4, Problem: 280.
# Epoch: 4, Problem: 281.
# Epoch: 4, Problem: 282.
# Epoch: 4, Problem: 283.
# Epoch: 4, Problem: 284.
# Epoch: 4, Problem: 285.
# Epoch: 4, Problem: 286.
# Epoch: 4, Problem: 287.
# Epoch: 4, Problem: 288.
# Epoch: 4, Problem: 289.
# Epoch: 4, Problem: 290.
# Epoch: 4, Problem: 291.
# Epoch: 4, Problem: 292.
# Epoch: 4, Problem: 293.
# Epoch: 4, Problem: 294.
# Epoch: 4, Problem: 295.
# Epoch: 4, Problem: 296.
# Epoch: 4, Problem: 297.
# Epoch: 4, Problem: 298.
# Epoch: 4, Problem: 299.
# Epoch: 4, Problem: 300.
# Epoch: 4, Problem: 301.
# Epoch: 4, Problem: 302.
# Epoch: 4, Problem: 303.
# Epoch: 4, Problem: 304.
# Epoch: 4, Problem: 305.
# Epoch: 4, Problem: 306.
# Epoch: 4, Problem: 307.
# Epoch: 4, Problem: 308.
# Epoch: 4, Problem: 309.
# Epoch: 4, Problem: 310.
# Epoch: 4, Problem: 311.
# Epoch: 4, Problem: 312.
# Epoch: 4, Problem: 313.
# Epoch: 4, Problem: 314.
# Epoch: 4, Problem: 315.
# Epoch: 4, Problem: 316.
# Epoch: 4, Problem: 317.
# Epoch: 4, Problem: 318.
# Epoch: 4, Problem: 319.
# Epoch: 4, Problem: 320.
# Epoch: 4, Problem: 321.
# Epoch: 4, Problem: 322.
# Epoch: 4, Problem: 323.
# Epoch: 4, Problem: 324.
# Epoch: 4, Problem: 325.
# Epoch: 4, Problem: 326.
# Epoch: 4, Problem: 327.
# Epoch: 4, Problem: 328.
# Epoch: 4, Problem: 329.
# Epoch: 4, Problem: 330.
# Epoch: 4, Problem: 331.
# Epoch: 4, Problem: 332.
# Epoch: 4, Problem: 333.
# Epoch: 4, Problem: 334.
# Epoch: 4, Problem: 335.
# Epoch: 4, Problem: 336.
# Epoch: 4, Problem: 337.
# Epoch: 4, Problem: 338.
# Epoch: 4, Problem: 339.
# Epoch: 4, Problem: 340.
# Epoch: 4, Problem: 341.
# Epoch: 4, Problem: 342.
# Epoch: 4, Problem: 343.
# Epoch: 4, Problem: 344.
# Epoch: 4, Problem: 345.
# Epoch: 4, Problem: 346.
# Epoch: 4, Problem: 347.
# Epoch: 4, Problem: 348.
# Epoch: 4, Problem: 349.
# Epoch: 4, Problem: 350.
# Epoch: 4, Problem: 351.
# Epoch: 4, Problem: 352.
# Epoch: 4, Problem: 353.
# Epoch: 4, Problem: 354.
# Epoch: 4, Problem: 355.
# Epoch: 4, Problem: 356.
# Epoch: 4, Problem: 357.
# Epoch: 4, Problem: 358.
# Epoch: 4, Problem: 359.
# Epoch: 4, Problem: 360.
# Epoch: 4, Problem: 361.
# Epoch: 4, Problem: 362.
# Epoch: 4, Problem: 363.
# Epoch: 4, Problem: 364.
# Epoch: 4, Problem: 365.
# Epoch: 4, Problem: 366.
# Epoch: 4, Problem: 367.
# Epoch: 4, Problem: 368.
# Epoch: 4, Problem: 369.
# Epoch: 4, Problem: 370.
# Epoch: 4, Problem: 371.
# Epoch: 4, Problem: 372.
# Epoch: 4, Problem: 373.
# Epoch: 4, Problem: 374.
# Epoch: 4, Problem: 375.
# Epoch: 4, Problem: 376.
# Epoch: 4, Problem: 377.
# Epoch: 4, Problem: 378.
# Epoch: 4, Problem: 379.
# Epoch: 4, Problem: 380.
# Epoch: 4, Problem: 381.
# Epoch: 4, Problem: 382.
# Epoch: 4, Problem: 383.
# Epoch: 4, Problem: 384.
# Epoch: 4, Problem: 385.
# Epoch: 4, Problem: 386.
# Epoch: 4, Problem: 387.
# Epoch: 4, Problem: 388.
# Epoch: 4, Problem: 389.
# Epoch: 4, Problem: 390.
# Epoch: 4, Problem: 391.
# Epoch: 4, Problem: 392.
# Epoch: 4, Problem: 393.
# Epoch: 4, Problem: 394.
# Epoch: 4, Problem: 395.
# Epoch: 4, Problem: 396.
# Epoch: 4, Problem: 397.
# Epoch: 4, Problem: 398.
# Epoch: 4, Problem: 399.
# Epoch: 4, Problem: 400.
# Epoch: 4, Problem: 401.
# Epoch: 4, Problem: 402.
# Epoch: 4, Problem: 403.
# Epoch: 4, Problem: 404.
# Epoch: 4, Problem: 405.
# Epoch: 4, Problem: 406.
# Epoch: 4, Problem: 407.
# Epoch: 4, Problem: 408.
# Epoch: 4, Problem: 409.
# Epoch: 4, Problem: 410.
# Epoch: 4, Problem: 411.
# Epoch: 4, Problem: 412.
# Epoch: 4, Problem: 413.
# Epoch: 4, Problem: 414.
# Epoch: 4, Problem: 415.
# Epoch: 4, Problem: 416.
# Epoch: 4, Problem: 417.
# Epoch: 4, Problem: 418.
# Epoch: 4, Problem: 419.
# Epoch: 4, Problem: 420.
# Epoch: 4, Problem: 421.
# Epoch: 4, Problem: 422.
# Epoch: 4, Problem: 423.
# Epoch: 4, Problem: 424.
# Epoch: 4, Problem: 425.
# Epoch: 4, Problem: 426.
# Epoch: 4, Problem: 427.
# Epoch: 4, Problem: 428.
# Epoch: 4, Problem: 429.
# Epoch: 4, Problem: 430.
# Epoch: 4, Problem: 431.
# Epoch: 4, Problem: 432.
# Epoch: 4, Problem: 433.
# Epoch: 4, Problem: 434.
# Epoch: 4, Problem: 435.
# Epoch: 4, Problem: 436.
# Epoch: 4, Problem: 437.
# Epoch: 4, Problem: 438.
# Epoch: 4, Problem: 439.
# Epoch: 4, Problem: 440.
# Epoch: 4, Problem: 441.
# Epoch: 4, Problem: 442.
# Epoch: 4, Problem: 443.
# Epoch: 4, Problem: 444.
# Epoch: 4, Problem: 445.
# Epoch: 4, Problem: 446.
# Epoch: 4, Problem: 447.
# Epoch: 4, Problem: 448.
# Epoch: 4, Problem: 449.
# Epoch: 4, Problem: 450.
# Epoch: 4, Problem: 451.
# Epoch: 4, Problem: 452.
# Epoch: 4, Problem: 453.
# Epoch: 4, Problem: 454.
# Epoch: 4, Problem: 455.
# Epoch: 4, Problem: 456.
# Epoch: 4, Problem: 457.
# Epoch: 4, Problem: 458.
# Epoch: 4, Problem: 459.
# Epoch: 4, Problem: 460.
# Epoch: 4, Problem: 461.
# Epoch: 4, Problem: 462.
# Epoch: 4, Problem: 463.
# Epoch: 4, Problem: 464.
# Epoch: 4, Problem: 465.
# Epoch: 4, Problem: 466.
# Epoch: 4, Problem: 467.
# Epoch: 4, Problem: 468.
# Epoch: 4, Problem: 469.
# Epoch: 4, Problem: 470.
# Epoch: 4, Problem: 471.
# Epoch: 4, Problem: 472.
# Epoch: 4, Problem: 473.
# Epoch: 4, Problem: 474.
# Epoch: 4, Problem: 475.
# Epoch: 4, Problem: 476.
# Epoch: 4, Problem: 477.
# Epoch: 4, Problem: 478.
# Epoch: 4, Problem: 479.
# Epoch: 4, Problem: 480.
# Epoch: 4, Problem: 481.
# Epoch: 4, Problem: 482.
# Epoch: 4, Problem: 483.
# Epoch: 4, Problem: 484.
# Epoch: 4, Problem: 485.
# Epoch: 4, Problem: 486.
# Epoch: 4, Problem: 487.
# Epoch: 4, Problem: 488.
# Epoch: 4, Problem: 489.
# Epoch: 4, Problem: 490.
# Epoch: 4, Problem: 491.
# Epoch: 4, Problem: 492.
# Epoch: 4, Problem: 493.
# Epoch: 4, Problem: 494.
# Epoch: 4, Problem: 495.
# Epoch: 4, Problem: 496.
# Epoch: 4, Problem: 497.
# Epoch: 4, Problem: 498.
# Epoch: 4, Problem: 499.
# Epoch: 4, Problem: 500.
# Epoch: 5, Problem: 1.
# Epoch: 5, Problem: 2.
# Epoch: 5, Problem: 3.
# Epoch: 5, Problem: 4.
# Epoch: 5, Problem: 5.
# Epoch: 5, Problem: 6.
# Epoch: 5, Problem: 7.
# Epoch: 5, Problem: 8.
# Epoch: 5, Problem: 9.
# Epoch: 5, Problem: 10.
# Epoch: 5, Problem: 11.
# Epoch: 5, Problem: 12.
# Epoch: 5, Problem: 13.
# Epoch: 5, Problem: 14.
# Epoch: 5, Problem: 15.
# Epoch: 5, Problem: 16.
# Epoch: 5, Problem: 17.
# Epoch: 5, Problem: 18.
# Epoch: 5, Problem: 19.
# Epoch: 5, Problem: 20.
# Epoch: 5, Problem: 21.
# Epoch: 5, Problem: 22.
# Epoch: 5, Problem: 23.
# Epoch: 5, Problem: 24.
# Epoch: 5, Problem: 25.
# Epoch: 5, Problem: 26.
# Epoch: 5, Problem: 27.
# Epoch: 5, Problem: 28.
# Epoch: 5, Problem: 29.
# Epoch: 5, Problem: 30.
# Epoch: 5, Problem: 31.
# Epoch: 5, Problem: 32.
# Epoch: 5, Problem: 33.
# Epoch: 5, Problem: 34.
# Epoch: 5, Problem: 35.
# Epoch: 5, Problem: 36.
# Epoch: 5, Problem: 37.
# Epoch: 5, Problem: 38.
# Epoch: 5, Problem: 39.
# Epoch: 5, Problem: 40.
# Epoch: 5, Problem: 41.
# Epoch: 5, Problem: 42.
# Epoch: 5, Problem: 43.
# Epoch: 5, Problem: 44.
# Epoch: 5, Problem: 45.
# Epoch: 5, Problem: 46.
# Epoch: 5, Problem: 47.
# Epoch: 5, Problem: 48.
# Epoch: 5, Problem: 49.
# Epoch: 5, Problem: 50.
# Epoch: 5, Problem: 51.
# Epoch: 5, Problem: 52.
# Epoch: 5, Problem: 53.
# Epoch: 5, Problem: 54.
# Epoch: 5, Problem: 55.
# Epoch: 5, Problem: 56.
# Epoch: 5, Problem: 57.
# Epoch: 5, Problem: 58.
# Epoch: 5, Problem: 59.
# Epoch: 5, Problem: 60.
# Epoch: 5, Problem: 61.
# Epoch: 5, Problem: 62.
# Epoch: 5, Problem: 63.
# Epoch: 5, Problem: 64.
# Epoch: 5, Problem: 65.
# Epoch: 5, Problem: 66.
# Epoch: 5, Problem: 67.
# Epoch: 5, Problem: 68.
# Epoch: 5, Problem: 69.
# Epoch: 5, Problem: 70.
# Epoch: 5, Problem: 71.
# Epoch: 5, Problem: 72.
# Epoch: 5, Problem: 73.
# Epoch: 5, Problem: 74.
# Epoch: 5, Problem: 75.
# Epoch: 5, Problem: 76.
# Epoch: 5, Problem: 77.
# Epoch: 5, Problem: 78.
# Epoch: 5, Problem: 79.
# Epoch: 5, Problem: 80.
# Epoch: 5, Problem: 81.
# Epoch: 5, Problem: 82.
# Epoch: 5, Problem: 83.
# Epoch: 5, Problem: 84.
# Epoch: 5, Problem: 85.
# Epoch: 5, Problem: 86.
# Epoch: 5, Problem: 87.
# Epoch: 5, Problem: 88.
# Epoch: 5, Problem: 89.
# Epoch: 5, Problem: 90.
# Epoch: 5, Problem: 91.
# Epoch: 5, Problem: 92.
# Epoch: 5, Problem: 93.
# Epoch: 5, Problem: 94.
# Epoch: 5, Problem: 95.
# Epoch: 5, Problem: 96.
# Epoch: 5, Problem: 97.
# Epoch: 5, Problem: 98.
# Epoch: 5, Problem: 99.
# Epoch: 5, Problem: 100.
# Epoch: 5, Problem: 101.
# Epoch: 5, Problem: 102.
# Epoch: 5, Problem: 103.
# Epoch: 5, Problem: 104.
# Epoch: 5, Problem: 105.
# Epoch: 5, Problem: 106.
# Epoch: 5, Problem: 107.
# Epoch: 5, Problem: 108.
# Epoch: 5, Problem: 109.
# Epoch: 5, Problem: 110.
# Epoch: 5, Problem: 111.
# Epoch: 5, Problem: 112.
# Epoch: 5, Problem: 113.
# Epoch: 5, Problem: 114.
# Epoch: 5, Problem: 115.
# Epoch: 5, Problem: 116.
# Epoch: 5, Problem: 117.
# Epoch: 5, Problem: 118.
# Epoch: 5, Problem: 119.
# Epoch: 5, Problem: 120.
# Epoch: 5, Problem: 121.
# Epoch: 5, Problem: 122.
# Epoch: 5, Problem: 123.
# Epoch: 5, Problem: 124.
# Epoch: 5, Problem: 125.
# Epoch: 5, Problem: 126.
# Epoch: 5, Problem: 127.
# Epoch: 5, Problem: 128.
# Epoch: 5, Problem: 129.
# Epoch: 5, Problem: 130.
# Epoch: 5, Problem: 131.
# Epoch: 5, Problem: 132.
# Epoch: 5, Problem: 133.
# Epoch: 5, Problem: 134.
# Epoch: 5, Problem: 135.
# Epoch: 5, Problem: 136.
# Epoch: 5, Problem: 137.
# Epoch: 5, Problem: 138.
# Epoch: 5, Problem: 139.
# Epoch: 5, Problem: 140.
# Epoch: 5, Problem: 141.
# Epoch: 5, Problem: 142.
# Epoch: 5, Problem: 143.
# Epoch: 5, Problem: 144.
# Epoch: 5, Problem: 145.
# Epoch: 5, Problem: 146.
# Epoch: 5, Problem: 147.
# Epoch: 5, Problem: 148.
# Epoch: 5, Problem: 149.
# Epoch: 5, Problem: 150.
# Epoch: 5, Problem: 151.
# Epoch: 5, Problem: 152.
# Epoch: 5, Problem: 153.
# Epoch: 5, Problem: 154.
# Epoch: 5, Problem: 155.
# Epoch: 5, Problem: 156.
# Epoch: 5, Problem: 157.
# Epoch: 5, Problem: 158.
# Epoch: 5, Problem: 159.
# Epoch: 5, Problem: 160.
# Epoch: 5, Problem: 161.
# Epoch: 5, Problem: 162.
# Epoch: 5, Problem: 163.
# Epoch: 5, Problem: 164.
# Epoch: 5, Problem: 165.
# Epoch: 5, Problem: 166.
# Epoch: 5, Problem: 167.
# Epoch: 5, Problem: 168.
# Epoch: 5, Problem: 169.
# Epoch: 5, Problem: 170.
# Epoch: 5, Problem: 171.
# Epoch: 5, Problem: 172.
# Epoch: 5, Problem: 173.
# Epoch: 5, Problem: 174.
# Epoch: 5, Problem: 175.
# Epoch: 5, Problem: 176.
# Epoch: 5, Problem: 177.
# Epoch: 5, Problem: 178.
# Epoch: 5, Problem: 179.
# Epoch: 5, Problem: 180.
# Epoch: 5, Problem: 181.
# Epoch: 5, Problem: 182.
# Epoch: 5, Problem: 183.
# Epoch: 5, Problem: 184.
# Epoch: 5, Problem: 185.
# Epoch: 5, Problem: 186.
# Epoch: 5, Problem: 187.
# Epoch: 5, Problem: 188.
# Epoch: 5, Problem: 189.
# Epoch: 5, Problem: 190.
# Epoch: 5, Problem: 191.
# Epoch: 5, Problem: 192.
# Epoch: 5, Problem: 193.
# Epoch: 5, Problem: 194.
# Epoch: 5, Problem: 195.
# Epoch: 5, Problem: 196.
# Epoch: 5, Problem: 197.
# Epoch: 5, Problem: 198.
# Epoch: 5, Problem: 199.
# Epoch: 5, Problem: 200.
# Epoch: 5, Problem: 201.
# Epoch: 5, Problem: 202.
# Epoch: 5, Problem: 203.
# Epoch: 5, Problem: 204.
# Epoch: 5, Problem: 205.
# Epoch: 5, Problem: 206.
# Epoch: 5, Problem: 207.
# Epoch: 5, Problem: 208.
# Epoch: 5, Problem: 209.
# Epoch: 5, Problem: 210.
# Epoch: 5, Problem: 211.
# Epoch: 5, Problem: 212.
# Epoch: 5, Problem: 213.
# Epoch: 5, Problem: 214.
# Epoch: 5, Problem: 215.
# Epoch: 5, Problem: 216.
# Epoch: 5, Problem: 217.
# Epoch: 5, Problem: 218.
# Epoch: 5, Problem: 219.
# Epoch: 5, Problem: 220.
# Epoch: 5, Problem: 221.
# Epoch: 5, Problem: 222.
# Epoch: 5, Problem: 223.
# Epoch: 5, Problem: 224.
# Epoch: 5, Problem: 225.
# Epoch: 5, Problem: 226.
# Epoch: 5, Problem: 227.
# Epoch: 5, Problem: 228.
# Epoch: 5, Problem: 229.
# Epoch: 5, Problem: 230.
# Epoch: 5, Problem: 231.
# Epoch: 5, Problem: 232.
# Epoch: 5, Problem: 233.
# Epoch: 5, Problem: 234.
# Epoch: 5, Problem: 235.
# Epoch: 5, Problem: 236.
# Epoch: 5, Problem: 237.
# Epoch: 5, Problem: 238.
# Epoch: 5, Problem: 239.
# Epoch: 5, Problem: 240.
# Epoch: 5, Problem: 241.
# Epoch: 5, Problem: 242.
# Epoch: 5, Problem: 243.
# Epoch: 5, Problem: 244.
# Epoch: 5, Problem: 245.
# Epoch: 5, Problem: 246.
# Epoch: 5, Problem: 247.
# Epoch: 5, Problem: 248.
# Epoch: 5, Problem: 249.
# Epoch: 5, Problem: 250.
# Epoch: 5, Problem: 251.
# Epoch: 5, Problem: 252.
# Epoch: 5, Problem: 253.
# Epoch: 5, Problem: 254.
# Epoch: 5, Problem: 255.
# Epoch: 5, Problem: 256.
# Epoch: 5, Problem: 257.
# Epoch: 5, Problem: 258.
# Epoch: 5, Problem: 259.
# Epoch: 5, Problem: 260.
# Epoch: 5, Problem: 261.
# Epoch: 5, Problem: 262.
# Epoch: 5, Problem: 263.
# Epoch: 5, Problem: 264.
# Epoch: 5, Problem: 265.
# Epoch: 5, Problem: 266.
# Epoch: 5, Problem: 267.
# Epoch: 5, Problem: 268.
# Epoch: 5, Problem: 269.
# Epoch: 5, Problem: 270.
# Epoch: 5, Problem: 271.
# Epoch: 5, Problem: 272.
# Epoch: 5, Problem: 273.
# Epoch: 5, Problem: 274.
# Epoch: 5, Problem: 275.
# Epoch: 5, Problem: 276.
# Epoch: 5, Problem: 277.
# Epoch: 5, Problem: 278.
# Epoch: 5, Problem: 279.
# Epoch: 5, Problem: 280.
# Epoch: 5, Problem: 281.
# Epoch: 5, Problem: 282.
# Epoch: 5, Problem: 283.
# Epoch: 5, Problem: 284.
# Epoch: 5, Problem: 285.
# Epoch: 5, Problem: 286.
# Epoch: 5, Problem: 287.
# Epoch: 5, Problem: 288.
# Epoch: 5, Problem: 289.
# Epoch: 5, Problem: 290.
# Epoch: 5, Problem: 291.
# Epoch: 5, Problem: 292.
# Epoch: 5, Problem: 293.
# Epoch: 5, Problem: 294.
# Epoch: 5, Problem: 295.
# Epoch: 5, Problem: 296.
# Epoch: 5, Problem: 297.
# Epoch: 5, Problem: 298.
# Epoch: 5, Problem: 299.
# Epoch: 5, Problem: 300.
# Epoch: 5, Problem: 301.
# Epoch: 5, Problem: 302.
# Epoch: 5, Problem: 303.
# Epoch: 5, Problem: 304.
# Epoch: 5, Problem: 305.
# Epoch: 5, Problem: 306.
# Epoch: 5, Problem: 307.
# Epoch: 5, Problem: 308.
# Epoch: 5, Problem: 309.
# Epoch: 5, Problem: 310.
# Epoch: 5, Problem: 311.
# Epoch: 5, Problem: 312.
# Epoch: 5, Problem: 313.
# Epoch: 5, Problem: 314.
# Epoch: 5, Problem: 315.
# Epoch: 5, Problem: 316.
# Epoch: 5, Problem: 317.
# Epoch: 5, Problem: 318.
# Epoch: 5, Problem: 319.
# Epoch: 5, Problem: 320.
# Epoch: 5, Problem: 321.
# Epoch: 5, Problem: 322.
# Epoch: 5, Problem: 323.
# Epoch: 5, Problem: 324.
# Epoch: 5, Problem: 325.
# Epoch: 5, Problem: 326.
# Epoch: 5, Problem: 327.
# Epoch: 5, Problem: 328.
# Epoch: 5, Problem: 329.
# Epoch: 5, Problem: 330.
# Epoch: 5, Problem: 331.
# Epoch: 5, Problem: 332.
# Epoch: 5, Problem: 333.
# Epoch: 5, Problem: 334.
# Epoch: 5, Problem: 335.
# Epoch: 5, Problem: 336.
# Epoch: 5, Problem: 337.
# Epoch: 5, Problem: 338.
# Epoch: 5, Problem: 339.
# Epoch: 5, Problem: 340.
# Epoch: 5, Problem: 341.
# Epoch: 5, Problem: 342.
# Epoch: 5, Problem: 343.
# Epoch: 5, Problem: 344.
# Epoch: 5, Problem: 345.
# Epoch: 5, Problem: 346.
# Epoch: 5, Problem: 347.
# Epoch: 5, Problem: 348.
# Epoch: 5, Problem: 349.
# Epoch: 5, Problem: 350.
# Epoch: 5, Problem: 351.
# Epoch: 5, Problem: 352.
# Epoch: 5, Problem: 353.
# Epoch: 5, Problem: 354.
# Epoch: 5, Problem: 355.
# Epoch: 5, Problem: 356.
# Epoch: 5, Problem: 357.
# Epoch: 5, Problem: 358.
# Epoch: 5, Problem: 359.
# Epoch: 5, Problem: 360.
# Epoch: 5, Problem: 361.
# Epoch: 5, Problem: 362.
# Epoch: 5, Problem: 363.
# Epoch: 5, Problem: 364.
# Epoch: 5, Problem: 365.
# Epoch: 5, Problem: 366.
# Epoch: 5, Problem: 367.
# Epoch: 5, Problem: 368.
# Epoch: 5, Problem: 369.
# Epoch: 5, Problem: 370.
# Epoch: 5, Problem: 371.
# Epoch: 5, Problem: 372.
# Epoch: 5, Problem: 373.
# Epoch: 5, Problem: 374.
# Epoch: 5, Problem: 375.
# Epoch: 5, Problem: 376.
# Epoch: 5, Problem: 377.
# Epoch: 5, Problem: 378.
# Epoch: 5, Problem: 379.
# Epoch: 5, Problem: 380.
# Epoch: 5, Problem: 381.
# Epoch: 5, Problem: 382.
# Epoch: 5, Problem: 383.
# Epoch: 5, Problem: 384.
# Epoch: 5, Problem: 385.
# Epoch: 5, Problem: 386.
# Epoch: 5, Problem: 387.
# Epoch: 5, Problem: 388.
# Epoch: 5, Problem: 389.
# Epoch: 5, Problem: 390.
# Epoch: 5, Problem: 391.
# Epoch: 5, Problem: 392.
# Epoch: 5, Problem: 393.
# Epoch: 5, Problem: 394.
# Epoch: 5, Problem: 395.
# Epoch: 5, Problem: 396.
# Epoch: 5, Problem: 397.
# Epoch: 5, Problem: 398.
# Epoch: 5, Problem: 399.
# Epoch: 5, Problem: 400.
# Epoch: 5, Problem: 401.
# Epoch: 5, Problem: 402.
# Epoch: 5, Problem: 403.
# Epoch: 5, Problem: 404.
# Epoch: 5, Problem: 405.
# Epoch: 5, Problem: 406.
# Epoch: 5, Problem: 407.
# Epoch: 5, Problem: 408.
# Epoch: 5, Problem: 409.
# Epoch: 5, Problem: 410.
# Epoch: 5, Problem: 411.
# Epoch: 5, Problem: 412.
# Epoch: 5, Problem: 413.
# Epoch: 5, Problem: 414.
# Epoch: 5, Problem: 415.
# Epoch: 5, Problem: 416.
# Epoch: 5, Problem: 417.
# Epoch: 5, Problem: 418.
# Epoch: 5, Problem: 419.
# Epoch: 5, Problem: 420.
# Epoch: 5, Problem: 421.
# Epoch: 5, Problem: 422.
# Epoch: 5, Problem: 423.
# Epoch: 5, Problem: 424.
# Epoch: 5, Problem: 425.
# Epoch: 5, Problem: 426.
# Epoch: 5, Problem: 427.
# Epoch: 5, Problem: 428.
# Epoch: 5, Problem: 429.
# Epoch: 5, Problem: 430.
# Epoch: 5, Problem: 431.
# Epoch: 5, Problem: 432.
# Epoch: 5, Problem: 433.
# Epoch: 5, Problem: 434.
# Epoch: 5, Problem: 435.
# Epoch: 5, Problem: 436.
# Epoch: 5, Problem: 437.
# Epoch: 5, Problem: 438.
# Epoch: 5, Problem: 439.
# Epoch: 5, Problem: 440.
# Epoch: 5, Problem: 441.
# Epoch: 5, Problem: 442.
# Epoch: 5, Problem: 443.
# Epoch: 5, Problem: 444.
# Epoch: 5, Problem: 445.
# Epoch: 5, Problem: 446.
# Epoch: 5, Problem: 447.
# Epoch: 5, Problem: 448.
# Epoch: 5, Problem: 449.
# Epoch: 5, Problem: 450.
# Epoch: 5, Problem: 451.
# Epoch: 5, Problem: 452.
# Epoch: 5, Problem: 453.
# Epoch: 5, Problem: 454.
# Epoch: 5, Problem: 455.
# Epoch: 5, Problem: 456.
# Epoch: 5, Problem: 457.
# Epoch: 5, Problem: 458.
# Epoch: 5, Problem: 459.
# Epoch: 5, Problem: 460.
# Epoch: 5, Problem: 461.
# Epoch: 5, Problem: 462.
# Epoch: 5, Problem: 463.
# Epoch: 5, Problem: 464.
# Epoch: 5, Problem: 465.
# Epoch: 5, Problem: 466.
# Epoch: 5, Problem: 467.
# Epoch: 5, Problem: 468.
# Epoch: 5, Problem: 469.
# Epoch: 5, Problem: 470.
# Epoch: 5, Problem: 471.
# Epoch: 5, Problem: 472.
# Epoch: 5, Problem: 473.
# Epoch: 5, Problem: 474.
# Epoch: 5, Problem: 475.
# Epoch: 5, Problem: 476.
# Epoch: 5, Problem: 477.
# Epoch: 5, Problem: 478.
# Epoch: 5, Problem: 479.
# Epoch: 5, Problem: 480.
# Epoch: 5, Problem: 481.
# Epoch: 5, Problem: 482.
# Epoch: 5, Problem: 483.
# Epoch: 5, Problem: 484.
# Epoch: 5, Problem: 485.
# Epoch: 5, Problem: 486.
# Epoch: 5, Problem: 487.
# Epoch: 5, Problem: 488.
# Epoch: 5, Problem: 489.
# Epoch: 5, Problem: 490.
# Epoch: 5, Problem: 491.
# Epoch: 5, Problem: 492.
# Epoch: 5, Problem: 493.
# Epoch: 5, Problem: 494.
# Epoch: 5, Problem: 495.
# Epoch: 5, Problem: 496.
# Epoch: 5, Problem: 497.
# Epoch: 5, Problem: 498.
# Epoch: 5, Problem: 499.
# Epoch: 5, Problem: 500.

# %%
import re

def clean_answer(answer):
    # Step 1: Remove common prefixes like "n=" and "k="
    answer = re.sub(r'\b[nk]\s*=\s*', '', answer)
    
    # Step 2: Normalize spaces around LaTeX commands
    answer = re.sub(r'\s*\\\s*', '\\', answer)
    
    # Step 3: Remove spaces before and after { and }
    answer = re.sub(r'\s*{\s*', '{', answer)
    answer = re.sub(r'\s*}\s*', '}', answer)
    
    # Step 4: Normalize spaces within text inside \text{}
    answer = re.sub(r'\\text{([^}]*)}', lambda m: f'\\text{{{m.group(1).strip()}}}', answer)
    
    # Step 5: Remove extra spaces
    answer = re.sub(r'\s+', ' ', answer).strip()
    
    return answer

def test_clean_answer():
    test_cases = [
        {"input": "25 \\text{ km}", "expected": "25 \\text{km}"},
        {"input": "25 \\, \\text{km}", "expected": "25 \\text{km}"},
        {"input": "\\16", "expected": "16"},
        {"input": "16", "expected": "16"},
        {"input": "k = 3", "expected": "3"},
        {"input": "n= 42", "expected": "42"},
        {"input": " \\boxed{ 42 }", "expected": "\\boxed{42}"}
    ]

    for idx, case in enumerate(test_cases):
        input_answer = case["input"]
        expected_output = case["expected"]
        cleaned_output = clean_answer(input_answer)
        assert cleaned_output == expected_output, f"Test case {idx + 1} failed: {cleaned_output} != {expected_output}"
        print(f"Test case {idx + 1} passed: {cleaned_output} == {expected_output}")

# Run the tests
test_clean_answer()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[187], line 41
#      38         print(f"Test case {idx + 1} passed: {cleaned_output} == {expected_output}")
#      40 # Run the tests
# ---> 41 test_clean_answer()
#
# Cell In[187], line 36, in test_clean_answer()
#      34 input_answer = case["input"]
#      35 expected_output = case["expected"]
# ---> 36 cleaned_output = clean_answer(input_answer)
#      37 assert cleaned_output == expected_output, f"Test case {idx + 1} failed: {cleaned_output} != {expected_output}"
#      38 print(f"Test case {idx + 1} passed: {cleaned_output} == {expected_output}")
#
# Cell In[187], line 8, in clean_answer(answer)
#       5 answer = re.sub(r'\b[nk]\s*=\s*', '', answer)
#       7 # Step 2: Normalize spaces around LaTeX commands
# ----> 8 answer = re.sub(r'\s*\\\s*', '\\', answer)
#      10 # Step 3: Remove spaces before and after { and }
#      11 answer = re.sub(r'\s*{\s*', '{', answer)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/re/__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/re/__init__.py:317, in _subx(pattern, template)
#     315 def _subx(pattern, template):
#     316     # internal: Pattern.sub/subn implementation helper
# --> 317     template = _compile_repl(template, pattern)
#     318     if not template[0] and len(template[1]) == 1:
#     319         # literal replacement
#     320         return template[1][0]
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/re/__init__.py:308, in _compile_repl(repl, pattern)
#     305 @functools.lru_cache(_MAXCACHE)
#     306 def _compile_repl(repl, pattern):
#     307     # internal: compile replacement pattern
# --> 308     return _parser.parse_template(repl, pattern)
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/re/_parser.py:1000, in parse_template(source, state)
#     997 def parse_template(source, state):
#     998     # parse 're' replacement string into list of literals and
#     999     # group references
# -> 1000     s = Tokenizer(source)
#    1001     sget = s.get
#    1002     groups = []
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/re/_parser.py:230, in Tokenizer.__init__(self, string)
#     228 self.index = 0
#     229 self.next = None
# --> 230 self.__next()
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/re/_parser.py:243, in Tokenizer.__next(self)
#     241         char += self.decoded_string[index]
#     242     except IndexError:
# --> 243         raise error("bad escape (end of pattern)",
#     244                     self.string, len(self.string) - 1) from None
#     245 self.index = index + 1
#     246 self.next = char
#
# error: bad escape (end of pattern) at position 0
